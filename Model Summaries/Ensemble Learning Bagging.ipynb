# %% [markdown]
# # Ensemble Learning: Bagging

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm_notebook as tqdm

# %% [markdown]
# ## Data

# %%
breast_cancer = pd.read_csv('../Data/breast_cancer.csv')
breast_cancer.drop(['id'], axis=1, inplace=True)
breast_cancer_dummies = pd.get_dummies(breast_cancer, columns=['diagnosis'], drop_first=True)
breast_cancer_dummies.rename(columns={'diagnosis_M': 'Malignant'}, inplace=True)
breast_cancer_dummies.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst  Malignant
# 0          0.4601                  0.11890          1
# 1          0.2750                  0.08902          1
# 2          0.3613                  0.08758          1
# 3          0.6638                  0.17300          1
# 4          0.2364                  0.07678          1
#
# [5 rows x 31 columns]

# %%
inputs = breast_cancer_dummies.drop(['Malignant'],axis=1)
target = breast_cancer_dummies.Malignant
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
X_train, X_test, y_train, y_test = train_test_split(inputs, target, test_size=0.2)

# %%
# Scale Data
X_train_scaled, X_test_scaled, y_train_scaled, y_test_scaled = train_test_split(StandardScaler().fit_transform(inputs), target, test_size=0.2)
X_train_scaled
# Out:
# array([[ 0.89825404,  0.66096886,  0.92393601, ...,  0.58156126,
#          0.26894679, -0.50460631],
#        [ 0.14561642, -0.56772258,  0.09230586, ..., -0.55312478,
#         -0.72113495, -0.99669876],
#        [-0.06455408, -0.01155354, -0.13341643, ..., -0.50409513,
#         -0.88129523, -0.43866148],
#        ...,
#        [-0.05319351, -1.42408329, -0.06833592, ..., -0.19956318,
#         -1.19838023, -0.63261684],
#        [ 0.03485089,  0.56555911,  0.06841555, ...,  0.45822582,
#          1.11666383,  0.96723781],
#        [-0.81151142, -1.4729517 , -0.77474785, ...,  0.26180272,
#          0.71545423,  0.4546415 ]])

# %% [markdown]
# ## Bagging Classifier
# Bootstrap Aggregation

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
bagModel = BaggingClassifier(
    base_estimator=RandomForestClassifier(),
    n_estimators=400,
    max_samples=0.8,
    oob_score=True, # Out of Bag Score,
    verbose=3,
)
bagModel.fit(X_train_scaled, y_train_scaled)
bagModel.oob_score_
# Out:
# Building estimator 165 of 1000 for this parallel run (total 1000)...
# Building estimator 166 of 1000 for this parallel run (total 1000)...
# Building estimator 167 of 1000 for this parallel run (total 1000)...
# Building estimator 168 of 1000 for this parallel run (total 1000)...
# Building estimator 169 of 1000 for this parallel run (total 1000)...
# Building estimator 170 of 1000 for this parallel run (total 1000)...
# Building estimator 171 of 1000 for this parallel run (total 1000)...
# Building estimator 172 of 1000 for this parallel run (total 1000)...
# Building estimator 173 of 1000 for this parallel run (total 1000)...
# Building estimator 174 of 1000 for this parallel run (total 1000)...
# Building estimator 175 of 1000 for this parallel run (total 1000)...
# Building estimator 176 of 1000 for this parallel run (total 1000)...
# Building estimator 177 of 1000 for this parallel run (total 1000)...
# Building estimator 178 of 1000 for this parallel run (total 1000)...
# Building estimator 179 of 1000 for this parallel run (total 1000)...
# Building estimator 180 of 1000 for this parallel run (total 1000)...
# Building estimator 181 of 1000 for this parallel run (total 1000)...
# Building estimator 182 of 1000 for this parallel run (total 1000)...
# Building estimator 183 of 1000 for this parallel run (total 1000)...
# Building estimator 184 of 1000 for this parallel run (total 1000)...
# Building estimator 185 of 1000 for this parallel run (total 1000)...
# Building estimator 186 of 1000 for this parallel run (total 1000)...
# Building estimator 187 of 1000 for this parallel run (total 1000)...
# Building estimator 188 of 1000 for this parallel run (total 1000)...
# Building estimator 189 of 1000 for this parallel run (total 1000)...
# Building estimator 190 of 1000 for this parallel run (total 1000)...
# Building estimator 191 of 1000 for this parallel run (total 1000)...
# Building estimator 192 of 1000 for this parallel run (total 1000)...
# Building estimator 193 of 1000 for this parallel run (total 1000)...
# Building estimator 194 of 1000 for this parallel run (total 1000)...
# Building estimator 195 of 1000 for this parallel run (total 1000)...
# Building estimator 196 of 1000 for this parallel run (total 1000)...
# Building estimator 197 of 1000 for this parallel run (total 1000)...
# Building estimator 198 of 1000 for this parallel run (total 1000)...
# Building estimator 199 of 1000 for this parallel run (total 1000)...
# Building estimator 200 of 1000 for this parallel run (total 1000)...
# Building estimator 201 of 1000 for this parallel run (total 1000)...
# Building estimator 202 of 1000 for this parallel run (total 1000)...
# Building estimator 203 of 1000 for this parallel run (total 1000)...
# Building estimator 204 of 1000 for this parallel run (total 1000)...
# Building estimator 205 of 1000 for this parallel run (total 1000)...
# Building estimator 206 of 1000 for this parallel run (total 1000)...
# Building estimator 207 of 1000 for this parallel run (total 1000)...
# Building estimator 208 of 1000 for this parallel run (total 1000)...
# Building estimator 209 of 1000 for this parallel run (total 1000)...
# Building estimator 210 of 1000 for this parallel run (total 1000)...
# Building estimator 211 of 1000 for this parallel run (total 1000)...
# Building estimator 212 of 1000 for this parallel run (total 1000)...
# Building estimator 213 of 1000 for this parallel run (total 1000)...
# Building estimator 214 of 1000 for this parallel run (total 1000)...
# Building estimator 215 of 1000 for this parallel run (total 1000)...
# Building estimator 216 of 1000 for this parallel run (total 1000)...
# Building estimator 217 of 1000 for this parallel run (total 1000)...
# Building estimator 218 of 1000 for this parallel run (total 1000)...
# Building estimator 219 of 1000 for this parallel run (total 1000)...
# Building estimator 220 of 1000 for this parallel run (total 1000)...
# Building estimator 221 of 1000 for this parallel run (total 1000)...
# Building estimator 222 of 1000 for this parallel run (total 1000)...
# Building estimator 223 of 1000 for this parallel run (total 1000)...
# Building estimator 224 of 1000 for this parallel run (total 1000)...
# Building estimator 225 of 1000 for this parallel run (total 1000)...
# Building estimator 226 of 1000 for this parallel run (total 1000)...
# Building estimator 227 of 1000 for this parallel run (total 1000)...
# Building estimator 228 of 1000 for this parallel run (total 1000)...
# Building estimator 229 of 1000 for this parallel run (total 1000)...
# Building estimator 230 of 1000 for this parallel run (total 1000)...
# Building estimator 231 of 1000 for this parallel run (total 1000)...
# Building estimator 232 of 1000 for this parallel run (total 1000)...
# Building estimator 233 of 1000 for this parallel run (total 1000)...
# Building estimator 234 of 1000 for this parallel run (total 1000)...
# Building estimator 235 of 1000 for this parallel run (total 1000)...
# Building estimator 236 of 1000 for this parallel run (total 1000)...
# Building estimator 237 of 1000 for this parallel run (total 1000)...
# Building estimator 238 of 1000 for this parallel run (total 1000)...
# Building estimator 239 of 1000 for this parallel run (total 1000)...
# Building estimator 240 of 1000 for this parallel run (total 1000)...
# Building estimator 241 of 1000 for this parallel run (total 1000)...
# Building estimator 242 of 1000 for this parallel run (total 1000)...
# Building estimator 243 of 1000 for this parallel run (total 1000)...
# Building estimator 244 of 1000 for this parallel run (total 1000)...
# Building estimator 245 of 1000 for this parallel run (total 1000)...
# Building estimator 246 of 1000 for this parallel run (total 1000)...
# Building estimator 247 of 1000 for this parallel run (total 1000)...
# Building estimator 248 of 1000 for this parallel run (total 1000)...
# Building estimator 249 of 1000 for this parallel run (total 1000)...
# Building estimator 250 of 1000 for this parallel run (total 1000)...
# Building estimator 251 of 1000 for this parallel run (total 1000)...
# Building estimator 252 of 1000 for this parallel run (total 1000)...
# Building estimator 253 of 1000 for this parallel run (total 1000)...
# Building estimator 254 of 1000 for this parallel run (total 1000)...
# Building estimator 255 of 1000 for this parallel run (total 1000)...
# Building estimator 256 of 1000 for this parallel run (total 1000)...
# Building estimator 257 of 1000 for this parallel run (total 1000)...
# Building estimator 258 of 1000 for this parallel run (total 1000)...
# Building estimator 259 of 1000 for this parallel run (total 1000)...
# Building estimator 260 of 1000 for this parallel run (total 1000)...
# Building estimator 261 of 1000 for this parallel run (total 1000)...
# Building estimator 262 of 1000 for this parallel run (total 1000)...
# Building estimator 263 of 1000 for this parallel run (total 1000)...
# Building estimator 264 of 1000 for this parallel run (total 1000)...
# Building estimator 265 of 1000 for this parallel run (total 1000)...
# Building estimator 266 of 1000 for this parallel run (total 1000)...
# Building estimator 267 of 1000 for this parallel run (total 1000)...
# Building estimator 268 of 1000 for this parallel run (total 1000)...
# Building estimator 269 of 1000 for this parallel run (total 1000)...
# Building estimator 270 of 1000 for this parallel run (total 1000)...
# Building estimator 271 of 1000 for this parallel run (total 1000)...
# Building estimator 272 of 1000 for this parallel run (total 1000)...
# Building estimator 273 of 1000 for this parallel run (total 1000)...
# Building estimator 274 of 1000 for this parallel run (total 1000)...
# Building estimator 275 of 1000 for this parallel run (total 1000)...
# Building estimator 276 of 1000 for this parallel run (total 1000)...
# Building estimator 277 of 1000 for this parallel run (total 1000)...
# Building estimator 278 of 1000 for this parallel run (total 1000)...
# Building estimator 279 of 1000 for this parallel run (total 1000)...
# Building estimator 280 of 1000 for this parallel run (total 1000)...
# Building estimator 281 of 1000 for this parallel run (total 1000)...
# Building estimator 282 of 1000 for this parallel run (total 1000)...
# Building estimator 283 of 1000 for this parallel run (total 1000)...
# Building estimator 284 of 1000 for this parallel run (total 1000)...
# Building estimator 285 of 1000 for this parallel run (total 1000)...
# Building estimator 286 of 1000 for this parallel run (total 1000)...
# Building estimator 287 of 1000 for this parallel run (total 1000)...
# Building estimator 288 of 1000 for this parallel run (total 1000)...
# Building estimator 289 of 1000 for this parallel run (total 1000)...
# Building estimator 290 of 1000 for this parallel run (total 1000)...
# Building estimator 291 of 1000 for this parallel run (total 1000)...
# Building estimator 292 of 1000 for this parallel run (total 1000)...
# Building estimator 293 of 1000 for this parallel run (total 1000)...
# Building estimator 294 of 1000 for this parallel run (total 1000)...
# Building estimator 295 of 1000 for this parallel run (total 1000)...
# Building estimator 296 of 1000 for this parallel run (total 1000)...
# Building estimator 297 of 1000 for this parallel run (total 1000)...
# Building estimator 298 of 1000 for this parallel run (total 1000)...
# Building estimator 299 of 1000 for this parallel run (total 1000)...
# Building estimator 300 of 1000 for this parallel run (total 1000)...
# Building estimator 301 of 1000 for this parallel run (total 1000)...
# Building estimator 302 of 1000 for this parallel run (total 1000)...
# Building estimator 303 of 1000 for this parallel run (total 1000)...
# Building estimator 304 of 1000 for this parallel run (total 1000)...
# Building estimator 305 of 1000 for this parallel run (total 1000)...
# Building estimator 306 of 1000 for this parallel run (total 1000)...
# Building estimator 307 of 1000 for this parallel run (total 1000)...
# Building estimator 308 of 1000 for this parallel run (total 1000)...
# Building estimator 309 of 1000 for this parallel run (total 1000)...
# Building estimator 310 of 1000 for this parallel run (total 1000)...
# Building estimator 311 of 1000 for this parallel run (total 1000)...
# Building estimator 312 of 1000 for this parallel run (total 1000)...
# Building estimator 313 of 1000 for this parallel run (total 1000)...
# Building estimator 314 of 1000 for this parallel run (total 1000)...
# Building estimator 315 of 1000 for this parallel run (total 1000)...
# Building estimator 316 of 1000 for this parallel run (total 1000)...
# Building estimator 317 of 1000 for this parallel run (total 1000)...
# Building estimator 318 of 1000 for this parallel run (total 1000)...
# Building estimator 319 of 1000 for this parallel run (total 1000)...
# Building estimator 320 of 1000 for this parallel run (total 1000)...
# Building estimator 321 of 1000 for this parallel run (total 1000)...
# Building estimator 322 of 1000 for this parallel run (total 1000)...
# Building estimator 323 of 1000 for this parallel run (total 1000)...
# Building estimator 324 of 1000 for this parallel run (total 1000)...
# Building estimator 325 of 1000 for this parallel run (total 1000)...
# Building estimator 326 of 1000 for this parallel run (total 1000)...
# Building estimator 327 of 1000 for this parallel run (total 1000)...
# Building estimator 328 of 1000 for this parallel run (total 1000)...
# Building estimator 329 of 1000 for this parallel run (total 1000)...
# Building estimator 330 of 1000 for this parallel run (total 1000)...
# Building estimator 331 of 1000 for this parallel run (total 1000)...
# Building estimator 332 of 1000 for this parallel run (total 1000)...
# Building estimator 333 of 1000 for this parallel run (total 1000)...
# Building estimator 334 of 1000 for this parallel run (total 1000)...
# Building estimator 335 of 1000 for this parallel run (total 1000)...
# Building estimator 336 of 1000 for this parallel run (total 1000)...
# Building estimator 337 of 1000 for this parallel run (total 1000)...
# Building estimator 338 of 1000 for this parallel run (total 1000)...
# Building estimator 339 of 1000 for this parallel run (total 1000)...
# Building estimator 340 of 1000 for this parallel run (total 1000)...
# Building estimator 341 of 1000 for this parallel run (total 1000)...
# Building estimator 342 of 1000 for this parallel run (total 1000)...
# Building estimator 343 of 1000 for this parallel run (total 1000)...
# Building estimator 344 of 1000 for this parallel run (total 1000)...
# Building estimator 345 of 1000 for this parallel run (total 1000)...
# Building estimator 346 of 1000 for this parallel run (total 1000)...
# Building estimator 347 of 1000 for this parallel run (total 1000)...
# Building estimator 348 of 1000 for this parallel run (total 1000)...
# Building estimator 349 of 1000 for this parallel run (total 1000)...
# Building estimator 350 of 1000 for this parallel run (total 1000)...
# Building estimator 351 of 1000 for this parallel run (total 1000)...
# Building estimator 352 of 1000 for this parallel run (total 1000)...
# Building estimator 353 of 1000 for this parallel run (total 1000)...
# Building estimator 354 of 1000 for this parallel run (total 1000)...
# Building estimator 355 of 1000 for this parallel run (total 1000)...
# Building estimator 356 of 1000 for this parallel run (total 1000)...
# Building estimator 357 of 1000 for this parallel run (total 1000)...
# Building estimator 358 of 1000 for this parallel run (total 1000)...
# Building estimator 359 of 1000 for this parallel run (total 1000)...
# Building estimator 360 of 1000 for this parallel run (total 1000)...
# Building estimator 361 of 1000 for this parallel run (total 1000)...
# Building estimator 362 of 1000 for this parallel run (total 1000)...
# Building estimator 363 of 1000 for this parallel run (total 1000)...
# Building estimator 364 of 1000 for this parallel run (total 1000)...
# Building estimator 365 of 1000 for this parallel run (total 1000)...
# Building estimator 366 of 1000 for this parallel run (total 1000)...
# Building estimator 367 of 1000 for this parallel run (total 1000)...
# Building estimator 368 of 1000 for this parallel run (total 1000)...
# Building estimator 369 of 1000 for this parallel run (total 1000)...
# Building estimator 370 of 1000 for this parallel run (total 1000)...
# Building estimator 371 of 1000 for this parallel run (total 1000)...
# Building estimator 372 of 1000 for this parallel run (total 1000)...
# Building estimator 373 of 1000 for this parallel run (total 1000)...
# Building estimator 374 of 1000 for this parallel run (total 1000)...
# Building estimator 375 of 1000 for this parallel run (total 1000)...
# Building estimator 376 of 1000 for this parallel run (total 1000)...
# Building estimator 377 of 1000 for this parallel run (total 1000)...
# Building estimator 378 of 1000 for this parallel run (total 1000)...
# Building estimator 379 of 1000 for this parallel run (total 1000)...
# Building estimator 380 of 1000 for this parallel run (total 1000)...
# Building estimator 381 of 1000 for this parallel run (total 1000)...
# Building estimator 382 of 1000 for this parallel run (total 1000)...
# Building estimator 383 of 1000 for this parallel run (total 1000)...
# Building estimator 384 of 1000 for this parallel run (total 1000)...
# Building estimator 385 of 1000 for this parallel run (total 1000)...
# Building estimator 386 of 1000 for this parallel run (total 1000)...
# Building estimator 387 of 1000 for this parallel run (total 1000)...
# Building estimator 388 of 1000 for this parallel run (total 1000)...
# Building estimator 389 of 1000 for this parallel run (total 1000)...
# Building estimator 390 of 1000 for this parallel run (total 1000)...
# Building estimator 391 of 1000 for this parallel run (total 1000)...
# Building estimator 392 of 1000 for this parallel run (total 1000)...
# Building estimator 393 of 1000 for this parallel run (total 1000)...
# Building estimator 394 of 1000 for this parallel run (total 1000)...
# Building estimator 395 of 1000 for this parallel run (total 1000)...
# Building estimator 396 of 1000 for this parallel run (total 1000)...
# Building estimator 397 of 1000 for this parallel run (total 1000)...
# Building estimator 398 of 1000 for this parallel run (total 1000)...
# Building estimator 399 of 1000 for this parallel run (total 1000)...
# Building estimator 400 of 1000 for this parallel run (total 1000)...
# Building estimator 401 of 1000 for this parallel run (total 1000)...
# Building estimator 402 of 1000 for this parallel run (total 1000)...
# Building estimator 403 of 1000 for this parallel run (total 1000)...
# Building estimator 404 of 1000 for this parallel run (total 1000)...
# Building estimator 405 of 1000 for this parallel run (total 1000)...
# Building estimator 406 of 1000 for this parallel run (total 1000)...
# Building estimator 407 of 1000 for this parallel run (total 1000)...
# Building estimator 408 of 1000 for this parallel run (total 1000)...
# Building estimator 409 of 1000 for this parallel run (total 1000)...
# Building estimator 410 of 1000 for this parallel run (total 1000)...
# Building estimator 411 of 1000 for this parallel run (total 1000)...
# Building estimator 412 of 1000 for this parallel run (total 1000)...
# Building estimator 413 of 1000 for this parallel run (total 1000)...
# Building estimator 414 of 1000 for this parallel run (total 1000)...
# Building estimator 415 of 1000 for this parallel run (total 1000)...
# Building estimator 416 of 1000 for this parallel run (total 1000)...
# Building estimator 417 of 1000 for this parallel run (total 1000)...
# Building estimator 418 of 1000 for this parallel run (total 1000)...
# Building estimator 419 of 1000 for this parallel run (total 1000)...
# Building estimator 420 of 1000 for this parallel run (total 1000)...
# Building estimator 421 of 1000 for this parallel run (total 1000)...
# Building estimator 422 of 1000 for this parallel run (total 1000)...
# Building estimator 423 of 1000 for this parallel run (total 1000)...
# Building estimator 424 of 1000 for this parallel run (total 1000)...
# Building estimator 425 of 1000 for this parallel run (total 1000)...
# Building estimator 426 of 1000 for this parallel run (total 1000)...
# Building estimator 427 of 1000 for this parallel run (total 1000)...
# Building estimator 428 of 1000 for this parallel run (total 1000)...
# Building estimator 429 of 1000 for this parallel run (total 1000)...
# Building estimator 430 of 1000 for this parallel run (total 1000)...
# Building estimator 431 of 1000 for this parallel run (total 1000)...
# Building estimator 432 of 1000 for this parallel run (total 1000)...
# Building estimator 433 of 1000 for this parallel run (total 1000)...
# Building estimator 434 of 1000 for this parallel run (total 1000)...
# Building estimator 435 of 1000 for this parallel run (total 1000)...
# Building estimator 436 of 1000 for this parallel run (total 1000)...
# Building estimator 437 of 1000 for this parallel run (total 1000)...
# Building estimator 438 of 1000 for this parallel run (total 1000)...
# Building estimator 439 of 1000 for this parallel run (total 1000)...
# Building estimator 440 of 1000 for this parallel run (total 1000)...
# Building estimator 441 of 1000 for this parallel run (total 1000)...
# Building estimator 442 of 1000 for this parallel run (total 1000)...
# Building estimator 443 of 1000 for this parallel run (total 1000)...
# Building estimator 444 of 1000 for this parallel run (total 1000)...
# Building estimator 445 of 1000 for this parallel run (total 1000)...
# Building estimator 446 of 1000 for this parallel run (total 1000)...
# Building estimator 447 of 1000 for this parallel run (total 1000)...
# Building estimator 448 of 1000 for this parallel run (total 1000)...
# Building estimator 449 of 1000 for this parallel run (total 1000)...
# Building estimator 450 of 1000 for this parallel run (total 1000)...
# Building estimator 451 of 1000 for this parallel run (total 1000)...
# Building estimator 452 of 1000 for this parallel run (total 1000)...
# Building estimator 453 of 1000 for this parallel run (total 1000)...
# Building estimator 454 of 1000 for this parallel run (total 1000)...
# Building estimator 455 of 1000 for this parallel run (total 1000)...
# Building estimator 456 of 1000 for this parallel run (total 1000)...
# Building estimator 457 of 1000 for this parallel run (total 1000)...
# Building estimator 458 of 1000 for this parallel run (total 1000)...
# Building estimator 459 of 1000 for this parallel run (total 1000)...
# Building estimator 460 of 1000 for this parallel run (total 1000)...
# Building estimator 461 of 1000 for this parallel run (total 1000)...
# Building estimator 462 of 1000 for this parallel run (total 1000)...
# Building estimator 463 of 1000 for this parallel run (total 1000)...
# Building estimator 464 of 1000 for this parallel run (total 1000)...
# Building estimator 465 of 1000 for this parallel run (total 1000)...
# Building estimator 466 of 1000 for this parallel run (total 1000)...
# Building estimator 467 of 1000 for this parallel run (total 1000)...
# Building estimator 468 of 1000 for this parallel run (total 1000)...
# Building estimator 469 of 1000 for this parallel run (total 1000)...
# Building estimator 470 of 1000 for this parallel run (total 1000)...
# Building estimator 471 of 1000 for this parallel run (total 1000)...
# Building estimator 472 of 1000 for this parallel run (total 1000)...
# Building estimator 473 of 1000 for this parallel run (total 1000)...
# Building estimator 474 of 1000 for this parallel run (total 1000)...
# Building estimator 475 of 1000 for this parallel run (total 1000)...
# Building estimator 476 of 1000 for this parallel run (total 1000)...
# Building estimator 477 of 1000 for this parallel run (total 1000)...
# Building estimator 478 of 1000 for this parallel run (total 1000)...
# Building estimator 479 of 1000 for this parallel run (total 1000)...
# Building estimator 480 of 1000 for this parallel run (total 1000)...
# Building estimator 481 of 1000 for this parallel run (total 1000)...
# Building estimator 482 of 1000 for this parallel run (total 1000)...
# Building estimator 483 of 1000 for this parallel run (total 1000)...
# Building estimator 484 of 1000 for this parallel run (total 1000)...
# Building estimator 485 of 1000 for this parallel run (total 1000)...
# Building estimator 486 of 1000 for this parallel run (total 1000)...
# Building estimator 487 of 1000 for this parallel run (total 1000)...
# Building estimator 488 of 1000 for this parallel run (total 1000)...
# Building estimator 489 of 1000 for this parallel run (total 1000)...
# Building estimator 490 of 1000 for this parallel run (total 1000)...
# Building estimator 491 of 1000 for this parallel run (total 1000)...
# Building estimator 492 of 1000 for this parallel run (total 1000)...
# Building estimator 493 of 1000 for this parallel run (total 1000)...
# Building estimator 494 of 1000 for this parallel run (total 1000)...
# Building estimator 495 of 1000 for this parallel run (total 1000)...
# Building estimator 496 of 1000 for this parallel run (total 1000)...
# Building estimator 497 of 1000 for this parallel run (total 1000)...
# Building estimator 498 of 1000 for this parallel run (total 1000)...
# Building estimator 499 of 1000 for this parallel run (total 1000)...
# Building estimator 500 of 1000 for this parallel run (total 1000)...
# Building estimator 501 of 1000 for this parallel run (total 1000)...
# Building estimator 502 of 1000 for this parallel run (total 1000)...
# Building estimator 503 of 1000 for this parallel run (total 1000)...
# Building estimator 504 of 1000 for this parallel run (total 1000)...
# Building estimator 505 of 1000 for this parallel run (total 1000)...
# Building estimator 506 of 1000 for this parallel run (total 1000)...
# Building estimator 507 of 1000 for this parallel run (total 1000)...
# Building estimator 508 of 1000 for this parallel run (total 1000)...
# Building estimator 509 of 1000 for this parallel run (total 1000)...
# Building estimator 510 of 1000 for this parallel run (total 1000)...
# Building estimator 511 of 1000 for this parallel run (total 1000)...
# Building estimator 512 of 1000 for this parallel run (total 1000)...
# Building estimator 513 of 1000 for this parallel run (total 1000)...
# Building estimator 514 of 1000 for this parallel run (total 1000)...
# Building estimator 515 of 1000 for this parallel run (total 1000)...
# Building estimator 516 of 1000 for this parallel run (total 1000)...
# Building estimator 517 of 1000 for this parallel run (total 1000)...
# Building estimator 518 of 1000 for this parallel run (total 1000)...
# Building estimator 519 of 1000 for this parallel run (total 1000)...
# Building estimator 520 of 1000 for this parallel run (total 1000)...
# Building estimator 521 of 1000 for this parallel run (total 1000)...
# Building estimator 522 of 1000 for this parallel run (total 1000)...
# Building estimator 523 of 1000 for this parallel run (total 1000)...
# Building estimator 524 of 1000 for this parallel run (total 1000)...
# Building estimator 525 of 1000 for this parallel run (total 1000)...
# Building estimator 526 of 1000 for this parallel run (total 1000)...
# Building estimator 527 of 1000 for this parallel run (total 1000)...
# Building estimator 528 of 1000 for this parallel run (total 1000)...
# Building estimator 529 of 1000 for this parallel run (total 1000)...
# Building estimator 530 of 1000 for this parallel run (total 1000)...
# Building estimator 531 of 1000 for this parallel run (total 1000)...
# Building estimator 532 of 1000 for this parallel run (total 1000)...
# Building estimator 533 of 1000 for this parallel run (total 1000)...
# Building estimator 534 of 1000 for this parallel run (total 1000)...
# Building estimator 535 of 1000 for this parallel run (total 1000)...
# Building estimator 536 of 1000 for this parallel run (total 1000)...
# Building estimator 537 of 1000 for this parallel run (total 1000)...
# Building estimator 538 of 1000 for this parallel run (total 1000)...
# Building estimator 539 of 1000 for this parallel run (total 1000)...
# Building estimator 540 of 1000 for this parallel run (total 1000)...
# Building estimator 541 of 1000 for this parallel run (total 1000)...
# Building estimator 542 of 1000 for this parallel run (total 1000)...
# Building estimator 543 of 1000 for this parallel run (total 1000)...
# Building estimator 544 of 1000 for this parallel run (total 1000)...
# Building estimator 545 of 1000 for this parallel run (total 1000)...
# Building estimator 546 of 1000 for this parallel run (total 1000)...
# Building estimator 547 of 1000 for this parallel run (total 1000)...
# Building estimator 548 of 1000 for this parallel run (total 1000)...
# Building estimator 549 of 1000 for this parallel run (total 1000)...
# Building estimator 550 of 1000 for this parallel run (total 1000)...
# Building estimator 551 of 1000 for this parallel run (total 1000)...
# Building estimator 552 of 1000 for this parallel run (total 1000)...
# Building estimator 553 of 1000 for this parallel run (total 1000)...
# Building estimator 554 of 1000 for this parallel run (total 1000)...
# Building estimator 555 of 1000 for this parallel run (total 1000)...
# Building estimator 556 of 1000 for this parallel run (total 1000)...
# Building estimator 557 of 1000 for this parallel run (total 1000)...
# Building estimator 558 of 1000 for this parallel run (total 1000)...
# Building estimator 559 of 1000 for this parallel run (total 1000)...
# Building estimator 560 of 1000 for this parallel run (total 1000)...
# Building estimator 561 of 1000 for this parallel run (total 1000)...
# Building estimator 562 of 1000 for this parallel run (total 1000)...
# Building estimator 563 of 1000 for this parallel run (total 1000)...
# Building estimator 564 of 1000 for this parallel run (total 1000)...
# Building estimator 565 of 1000 for this parallel run (total 1000)...
# Building estimator 566 of 1000 for this parallel run (total 1000)...
# Building estimator 567 of 1000 for this parallel run (total 1000)...
# Building estimator 568 of 1000 for this parallel run (total 1000)...
# Building estimator 569 of 1000 for this parallel run (total 1000)...
# Building estimator 570 of 1000 for this parallel run (total 1000)...
# Building estimator 571 of 1000 for this parallel run (total 1000)...
# Building estimator 572 of 1000 for this parallel run (total 1000)...
# Building estimator 573 of 1000 for this parallel run (total 1000)...
# Building estimator 574 of 1000 for this parallel run (total 1000)...
# Building estimator 575 of 1000 for this parallel run (total 1000)...
# Building estimator 576 of 1000 for this parallel run (total 1000)...
# Building estimator 577 of 1000 for this parallel run (total 1000)...
# Building estimator 578 of 1000 for this parallel run (total 1000)...
# Building estimator 579 of 1000 for this parallel run (total 1000)...
# Building estimator 580 of 1000 for this parallel run (total 1000)...
# Building estimator 581 of 1000 for this parallel run (total 1000)...
# Building estimator 582 of 1000 for this parallel run (total 1000)...
# Building estimator 583 of 1000 for this parallel run (total 1000)...
# Building estimator 584 of 1000 for this parallel run (total 1000)...
# Building estimator 585 of 1000 for this parallel run (total 1000)...
# Building estimator 586 of 1000 for this parallel run (total 1000)...
# Building estimator 587 of 1000 for this parallel run (total 1000)...
# Building estimator 588 of 1000 for this parallel run (total 1000)...
# Building estimator 589 of 1000 for this parallel run (total 1000)...
# Building estimator 590 of 1000 for this parallel run (total 1000)...
# Building estimator 591 of 1000 for this parallel run (total 1000)...
# Building estimator 592 of 1000 for this parallel run (total 1000)...
# Building estimator 593 of 1000 for this parallel run (total 1000)...
# Building estimator 594 of 1000 for this parallel run (total 1000)...
# Building estimator 595 of 1000 for this parallel run (total 1000)...
# Building estimator 596 of 1000 for this parallel run (total 1000)...
# Building estimator 597 of 1000 for this parallel run (total 1000)...
# Building estimator 598 of 1000 for this parallel run (total 1000)...
# Building estimator 599 of 1000 for this parallel run (total 1000)...
# Building estimator 600 of 1000 for this parallel run (total 1000)...
# Building estimator 601 of 1000 for this parallel run (total 1000)...
# Building estimator 602 of 1000 for this parallel run (total 1000)...
# Building estimator 603 of 1000 for this parallel run (total 1000)...
# Building estimator 604 of 1000 for this parallel run (total 1000)...
# Building estimator 605 of 1000 for this parallel run (total 1000)...
# Building estimator 606 of 1000 for this parallel run (total 1000)...
# Building estimator 607 of 1000 for this parallel run (total 1000)...
# Building estimator 608 of 1000 for this parallel run (total 1000)...
# Building estimator 609 of 1000 for this parallel run (total 1000)...
# Building estimator 610 of 1000 for this parallel run (total 1000)...
# Building estimator 611 of 1000 for this parallel run (total 1000)...
# Building estimator 612 of 1000 for this parallel run (total 1000)...
# Building estimator 613 of 1000 for this parallel run (total 1000)...
# Building estimator 614 of 1000 for this parallel run (total 1000)...
# Building estimator 615 of 1000 for this parallel run (total 1000)...
# Building estimator 616 of 1000 for this parallel run (total 1000)...
# Building estimator 617 of 1000 for this parallel run (total 1000)...
# Building estimator 618 of 1000 for this parallel run (total 1000)...
# Building estimator 619 of 1000 for this parallel run (total 1000)...
# Building estimator 620 of 1000 for this parallel run (total 1000)...
# Building estimator 621 of 1000 for this parallel run (total 1000)...
# Building estimator 622 of 1000 for this parallel run (total 1000)...
# Building estimator 623 of 1000 for this parallel run (total 1000)...
# Building estimator 624 of 1000 for this parallel run (total 1000)...
# Building estimator 625 of 1000 for this parallel run (total 1000)...
# Building estimator 626 of 1000 for this parallel run (total 1000)...
# Building estimator 627 of 1000 for this parallel run (total 1000)...
# Building estimator 628 of 1000 for this parallel run (total 1000)...
# Building estimator 629 of 1000 for this parallel run (total 1000)...
# Building estimator 630 of 1000 for this parallel run (total 1000)...
# Building estimator 631 of 1000 for this parallel run (total 1000)...
# Building estimator 632 of 1000 for this parallel run (total 1000)...
# Building estimator 633 of 1000 for this parallel run (total 1000)...
# Building estimator 634 of 1000 for this parallel run (total 1000)...
# Building estimator 635 of 1000 for this parallel run (total 1000)...
# Building estimator 636 of 1000 for this parallel run (total 1000)...
# Building estimator 637 of 1000 for this parallel run (total 1000)...
# Building estimator 638 of 1000 for this parallel run (total 1000)...
# Building estimator 639 of 1000 for this parallel run (total 1000)...
# Building estimator 640 of 1000 for this parallel run (total 1000)...
# Building estimator 641 of 1000 for this parallel run (total 1000)...
# Building estimator 642 of 1000 for this parallel run (total 1000)...
# Building estimator 643 of 1000 for this parallel run (total 1000)...
# Building estimator 644 of 1000 for this parallel run (total 1000)...
# Building estimator 645 of 1000 for this parallel run (total 1000)...
# Building estimator 646 of 1000 for this parallel run (total 1000)...
# Building estimator 647 of 1000 for this parallel run (total 1000)...
# Building estimator 648 of 1000 for this parallel run (total 1000)...
# Building estimator 649 of 1000 for this parallel run (total 1000)...
# Building estimator 650 of 1000 for this parallel run (total 1000)...
# Building estimator 651 of 1000 for this parallel run (total 1000)...
# Building estimator 652 of 1000 for this parallel run (total 1000)...
# Building estimator 653 of 1000 for this parallel run (total 1000)...
# Building estimator 654 of 1000 for this parallel run (total 1000)...
# Building estimator 655 of 1000 for this parallel run (total 1000)...
# Building estimator 656 of 1000 for this parallel run (total 1000)...
# Building estimator 657 of 1000 for this parallel run (total 1000)...
# Building estimator 658 of 1000 for this parallel run (total 1000)...
# Building estimator 659 of 1000 for this parallel run (total 1000)...
# Building estimator 660 of 1000 for this parallel run (total 1000)...
# Building estimator 661 of 1000 for this parallel run (total 1000)...
# Building estimator 662 of 1000 for this parallel run (total 1000)...
# Building estimator 663 of 1000 for this parallel run (total 1000)...
# Building estimator 664 of 1000 for this parallel run (total 1000)...
# Building estimator 665 of 1000 for this parallel run (total 1000)...
# Building estimator 666 of 1000 for this parallel run (total 1000)...
# Building estimator 667 of 1000 for this parallel run (total 1000)...
# Building estimator 668 of 1000 for this parallel run (total 1000)...
# Building estimator 669 of 1000 for this parallel run (total 1000)...
# Building estimator 670 of 1000 for this parallel run (total 1000)...
# Building estimator 671 of 1000 for this parallel run (total 1000)...
# Building estimator 672 of 1000 for this parallel run (total 1000)...
# Building estimator 673 of 1000 for this parallel run (total 1000)...
# Building estimator 674 of 1000 for this parallel run (total 1000)...
# Building estimator 675 of 1000 for this parallel run (total 1000)...
# Building estimator 676 of 1000 for this parallel run (total 1000)...
# Building estimator 677 of 1000 for this parallel run (total 1000)...
# Building estimator 678 of 1000 for this parallel run (total 1000)...
# Building estimator 679 of 1000 for this parallel run (total 1000)...
# Building estimator 680 of 1000 for this parallel run (total 1000)...
# Building estimator 681 of 1000 for this parallel run (total 1000)...
# Building estimator 682 of 1000 for this parallel run (total 1000)...
# Building estimator 683 of 1000 for this parallel run (total 1000)...
# Building estimator 684 of 1000 for this parallel run (total 1000)...
# Building estimator 685 of 1000 for this parallel run (total 1000)...
# Building estimator 686 of 1000 for this parallel run (total 1000)...
# Building estimator 687 of 1000 for this parallel run (total 1000)...
# Building estimator 688 of 1000 for this parallel run (total 1000)...
# Building estimator 689 of 1000 for this parallel run (total 1000)...
# Building estimator 690 of 1000 for this parallel run (total 1000)...
# Building estimator 691 of 1000 for this parallel run (total 1000)...
# Building estimator 692 of 1000 for this parallel run (total 1000)...
# Building estimator 693 of 1000 for this parallel run (total 1000)...
# Building estimator 694 of 1000 for this parallel run (total 1000)...
# Building estimator 695 of 1000 for this parallel run (total 1000)...
# Building estimator 696 of 1000 for this parallel run (total 1000)...
# Building estimator 697 of 1000 for this parallel run (total 1000)...
# Building estimator 698 of 1000 for this parallel run (total 1000)...
# Building estimator 699 of 1000 for this parallel run (total 1000)...
# Building estimator 700 of 1000 for this parallel run (total 1000)...
# Building estimator 701 of 1000 for this parallel run (total 1000)...
# Building estimator 702 of 1000 for this parallel run (total 1000)...
# Building estimator 703 of 1000 for this parallel run (total 1000)...
# Building estimator 704 of 1000 for this parallel run (total 1000)...
# Building estimator 705 of 1000 for this parallel run (total 1000)...
# Building estimator 706 of 1000 for this parallel run (total 1000)...
# Building estimator 707 of 1000 for this parallel run (total 1000)...
# Building estimator 708 of 1000 for this parallel run (total 1000)...
# Building estimator 709 of 1000 for this parallel run (total 1000)...
# Building estimator 710 of 1000 for this parallel run (total 1000)...
# Building estimator 711 of 1000 for this parallel run (total 1000)...
# Building estimator 712 of 1000 for this parallel run (total 1000)...
# Building estimator 713 of 1000 for this parallel run (total 1000)...
# Building estimator 714 of 1000 for this parallel run (total 1000)...
# Building estimator 715 of 1000 for this parallel run (total 1000)...
# Building estimator 716 of 1000 for this parallel run (total 1000)...
# Building estimator 717 of 1000 for this parallel run (total 1000)...
# Building estimator 718 of 1000 for this parallel run (total 1000)...
# Building estimator 719 of 1000 for this parallel run (total 1000)...
# Building estimator 720 of 1000 for this parallel run (total 1000)...
# Building estimator 721 of 1000 for this parallel run (total 1000)...
# Building estimator 722 of 1000 for this parallel run (total 1000)...
# Building estimator 723 of 1000 for this parallel run (total 1000)...
# Building estimator 724 of 1000 for this parallel run (total 1000)...
# Building estimator 725 of 1000 for this parallel run (total 1000)...
# Building estimator 726 of 1000 for this parallel run (total 1000)...
# Building estimator 727 of 1000 for this parallel run (total 1000)...
# Building estimator 728 of 1000 for this parallel run (total 1000)...
# Building estimator 729 of 1000 for this parallel run (total 1000)...
# Building estimator 730 of 1000 for this parallel run (total 1000)...
# Building estimator 731 of 1000 for this parallel run (total 1000)...
# Building estimator 732 of 1000 for this parallel run (total 1000)...
# Building estimator 733 of 1000 for this parallel run (total 1000)...
# Building estimator 734 of 1000 for this parallel run (total 1000)...
# Building estimator 735 of 1000 for this parallel run (total 1000)...
# Building estimator 736 of 1000 for this parallel run (total 1000)...
# Building estimator 737 of 1000 for this parallel run (total 1000)...
# Building estimator 738 of 1000 for this parallel run (total 1000)...
# Building estimator 739 of 1000 for this parallel run (total 1000)...
# Building estimator 740 of 1000 for this parallel run (total 1000)...
# Building estimator 741 of 1000 for this parallel run (total 1000)...
# Building estimator 742 of 1000 for this parallel run (total 1000)...
# Building estimator 743 of 1000 for this parallel run (total 1000)...
# Building estimator 744 of 1000 for this parallel run (total 1000)...
# Building estimator 745 of 1000 for this parallel run (total 1000)...
# Building estimator 746 of 1000 for this parallel run (total 1000)...
# Building estimator 747 of 1000 for this parallel run (total 1000)...
# Building estimator 748 of 1000 for this parallel run (total 1000)...
# Building estimator 749 of 1000 for this parallel run (total 1000)...
# Building estimator 750 of 1000 for this parallel run (total 1000)...
# Building estimator 751 of 1000 for this parallel run (total 1000)...
# Building estimator 752 of 1000 for this parallel run (total 1000)...
# Building estimator 753 of 1000 for this parallel run (total 1000)...
# Building estimator 754 of 1000 for this parallel run (total 1000)...
# Building estimator 755 of 1000 for this parallel run (total 1000)...
# Building estimator 756 of 1000 for this parallel run (total 1000)...
# Building estimator 757 of 1000 for this parallel run (total 1000)...
# Building estimator 758 of 1000 for this parallel run (total 1000)...
# Building estimator 759 of 1000 for this parallel run (total 1000)...
# Building estimator 760 of 1000 for this parallel run (total 1000)...
# Building estimator 761 of 1000 for this parallel run (total 1000)...
# Building estimator 762 of 1000 for this parallel run (total 1000)...
# Building estimator 763 of 1000 for this parallel run (total 1000)...
# Building estimator 764 of 1000 for this parallel run (total 1000)...
# Building estimator 765 of 1000 for this parallel run (total 1000)...
# Building estimator 766 of 1000 for this parallel run (total 1000)...
# Building estimator 767 of 1000 for this parallel run (total 1000)...
# Building estimator 768 of 1000 for this parallel run (total 1000)...
# Building estimator 769 of 1000 for this parallel run (total 1000)...
# Building estimator 770 of 1000 for this parallel run (total 1000)...
# Building estimator 771 of 1000 for this parallel run (total 1000)...
# Building estimator 772 of 1000 for this parallel run (total 1000)...
# Building estimator 773 of 1000 for this parallel run (total 1000)...
# Building estimator 774 of 1000 for this parallel run (total 1000)...
# Building estimator 775 of 1000 for this parallel run (total 1000)...
# Building estimator 776 of 1000 for this parallel run (total 1000)...
# Building estimator 777 of 1000 for this parallel run (total 1000)...
# Building estimator 778 of 1000 for this parallel run (total 1000)...
# Building estimator 779 of 1000 for this parallel run (total 1000)...
# Building estimator 780 of 1000 for this parallel run (total 1000)...
# Building estimator 781 of 1000 for this parallel run (total 1000)...
# Building estimator 782 of 1000 for this parallel run (total 1000)...
# Building estimator 783 of 1000 for this parallel run (total 1000)...
# Building estimator 784 of 1000 for this parallel run (total 1000)...
# Building estimator 785 of 1000 for this parallel run (total 1000)...
# Building estimator 786 of 1000 for this parallel run (total 1000)...
# Building estimator 787 of 1000 for this parallel run (total 1000)...
# Building estimator 788 of 1000 for this parallel run (total 1000)...
# Building estimator 789 of 1000 for this parallel run (total 1000)...
# Building estimator 790 of 1000 for this parallel run (total 1000)...
# Building estimator 791 of 1000 for this parallel run (total 1000)...
# Building estimator 792 of 1000 for this parallel run (total 1000)...
# Building estimator 793 of 1000 for this parallel run (total 1000)...
# Building estimator 794 of 1000 for this parallel run (total 1000)...
# Building estimator 795 of 1000 for this parallel run (total 1000)...
# Building estimator 796 of 1000 for this parallel run (total 1000)...
# Building estimator 797 of 1000 for this parallel run (total 1000)...
# Building estimator 798 of 1000 for this parallel run (total 1000)...
# Building estimator 799 of 1000 for this parallel run (total 1000)...
# Building estimator 800 of 1000 for this parallel run (total 1000)...
# Building estimator 801 of 1000 for this parallel run (total 1000)...
# Building estimator 802 of 1000 for this parallel run (total 1000)...
# Building estimator 803 of 1000 for this parallel run (total 1000)...
# Building estimator 804 of 1000 for this parallel run (total 1000)...
# Building estimator 805 of 1000 for this parallel run (total 1000)...
# Building estimator 806 of 1000 for this parallel run (total 1000)...
# Building estimator 807 of 1000 for this parallel run (total 1000)...
# Building estimator 808 of 1000 for this parallel run (total 1000)...
# Building estimator 809 of 1000 for this parallel run (total 1000)...
# Building estimator 810 of 1000 for this parallel run (total 1000)...
# Building estimator 811 of 1000 for this parallel run (total 1000)...
# Building estimator 812 of 1000 for this parallel run (total 1000)...
# Building estimator 813 of 1000 for this parallel run (total 1000)...
# Building estimator 814 of 1000 for this parallel run (total 1000)...
# Building estimator 815 of 1000 for this parallel run (total 1000)...
# Building estimator 816 of 1000 for this parallel run (total 1000)...
# Building estimator 817 of 1000 for this parallel run (total 1000)...
# Building estimator 818 of 1000 for this parallel run (total 1000)...
# Building estimator 819 of 1000 for this parallel run (total 1000)...
# Building estimator 820 of 1000 for this parallel run (total 1000)...
# Building estimator 821 of 1000 for this parallel run (total 1000)...
# Building estimator 822 of 1000 for this parallel run (total 1000)...
# Building estimator 823 of 1000 for this parallel run (total 1000)...
# Building estimator 824 of 1000 for this parallel run (total 1000)...
# Building estimator 825 of 1000 for this parallel run (total 1000)...
# Building estimator 826 of 1000 for this parallel run (total 1000)...
# Building estimator 827 of 1000 for this parallel run (total 1000)...
# Building estimator 828 of 1000 for this parallel run (total 1000)...
# Building estimator 829 of 1000 for this parallel run (total 1000)...
# Building estimator 830 of 1000 for this parallel run (total 1000)...
# Building estimator 831 of 1000 for this parallel run (total 1000)...
# Building estimator 832 of 1000 for this parallel run (total 1000)...
# Building estimator 833 of 1000 for this parallel run (total 1000)...
# Building estimator 834 of 1000 for this parallel run (total 1000)...
# Building estimator 835 of 1000 for this parallel run (total 1000)...
# Building estimator 836 of 1000 for this parallel run (total 1000)...
# Building estimator 837 of 1000 for this parallel run (total 1000)...
# Building estimator 838 of 1000 for this parallel run (total 1000)...
# Building estimator 839 of 1000 for this parallel run (total 1000)...
# Building estimator 840 of 1000 for this parallel run (total 1000)...
# Building estimator 841 of 1000 for this parallel run (total 1000)...
# Building estimator 842 of 1000 for this parallel run (total 1000)...
# Building estimator 843 of 1000 for this parallel run (total 1000)...
# Building estimator 844 of 1000 for this parallel run (total 1000)...
# Building estimator 845 of 1000 for this parallel run (total 1000)...
# Building estimator 846 of 1000 for this parallel run (total 1000)...
# Building estimator 847 of 1000 for this parallel run (total 1000)...
# Building estimator 848 of 1000 for this parallel run (total 1000)...
# Building estimator 849 of 1000 for this parallel run (total 1000)...
# Building estimator 850 of 1000 for this parallel run (total 1000)...
# Building estimator 851 of 1000 for this parallel run (total 1000)...
# Building estimator 852 of 1000 for this parallel run (total 1000)...
# Building estimator 853 of 1000 for this parallel run (total 1000)...
# Building estimator 854 of 1000 for this parallel run (total 1000)...
# Building estimator 855 of 1000 for this parallel run (total 1000)...
# Building estimator 856 of 1000 for this parallel run (total 1000)...
# Building estimator 857 of 1000 for this parallel run (total 1000)...
# Building estimator 858 of 1000 for this parallel run (total 1000)...
# Building estimator 859 of 1000 for this parallel run (total 1000)...
# ...
# Building estimator 165 of 400 for this parallel run (total 400)...
# Building estimator 166 of 400 for this parallel run (total 400)...
# Building estimator 167 of 400 for this parallel run (total 400)...
# Building estimator 168 of 400 for this parallel run (total 400)...
# Building estimator 169 of 400 for this parallel run (total 400)...
# Building estimator 170 of 400 for this parallel run (total 400)...
# Building estimator 171 of 400 for this parallel run (total 400)...
# Building estimator 172 of 400 for this parallel run (total 400)...
# Building estimator 173 of 400 for this parallel run (total 400)...
# Building estimator 174 of 400 for this parallel run (total 400)...
# Building estimator 175 of 400 for this parallel run (total 400)...
# Building estimator 176 of 400 for this parallel run (total 400)...
# Building estimator 177 of 400 for this parallel run (total 400)...
# Building estimator 178 of 400 for this parallel run (total 400)...
# Building estimator 179 of 400 for this parallel run (total 400)...
# Building estimator 180 of 400 for this parallel run (total 400)...
# Building estimator 181 of 400 for this parallel run (total 400)...
# Building estimator 182 of 400 for this parallel run (total 400)...
# Building estimator 183 of 400 for this parallel run (total 400)...
# Building estimator 184 of 400 for this parallel run (total 400)...
# Building estimator 185 of 400 for this parallel run (total 400)...
# Building estimator 186 of 400 for this parallel run (total 400)...
# Building estimator 187 of 400 for this parallel run (total 400)...
# Building estimator 188 of 400 for this parallel run (total 400)...
# Building estimator 189 of 400 for this parallel run (total 400)...
# Building estimator 190 of 400 for this parallel run (total 400)...
# Building estimator 191 of 400 for this parallel run (total 400)...
# Building estimator 192 of 400 for this parallel run (total 400)...
# Building estimator 193 of 400 for this parallel run (total 400)...
# Building estimator 194 of 400 for this parallel run (total 400)...
# Building estimator 195 of 400 for this parallel run (total 400)...
# Building estimator 196 of 400 for this parallel run (total 400)...
# Building estimator 197 of 400 for this parallel run (total 400)...
# Building estimator 198 of 400 for this parallel run (total 400)...
# Building estimator 199 of 400 for this parallel run (total 400)...
# Building estimator 200 of 400 for this parallel run (total 400)...
# Building estimator 201 of 400 for this parallel run (total 400)...
# Building estimator 202 of 400 for this parallel run (total 400)...
# Building estimator 203 of 400 for this parallel run (total 400)...
# Building estimator 204 of 400 for this parallel run (total 400)...
# Building estimator 205 of 400 for this parallel run (total 400)...
# Building estimator 206 of 400 for this parallel run (total 400)...
# Building estimator 207 of 400 for this parallel run (total 400)...
# Building estimator 208 of 400 for this parallel run (total 400)...
# Building estimator 209 of 400 for this parallel run (total 400)...
# Building estimator 210 of 400 for this parallel run (total 400)...
# Building estimator 211 of 400 for this parallel run (total 400)...
# Building estimator 212 of 400 for this parallel run (total 400)...
# Building estimator 213 of 400 for this parallel run (total 400)...
# Building estimator 214 of 400 for this parallel run (total 400)...
# Building estimator 215 of 400 for this parallel run (total 400)...
# Building estimator 216 of 400 for this parallel run (total 400)...
# Building estimator 217 of 400 for this parallel run (total 400)...
# Building estimator 218 of 400 for this parallel run (total 400)...
# Building estimator 219 of 400 for this parallel run (total 400)...
# Building estimator 220 of 400 for this parallel run (total 400)...
# Building estimator 221 of 400 for this parallel run (total 400)...
# Building estimator 222 of 400 for this parallel run (total 400)...
# Building estimator 223 of 400 for this parallel run (total 400)...
# Building estimator 224 of 400 for this parallel run (total 400)...
# Building estimator 225 of 400 for this parallel run (total 400)...
# Building estimator 226 of 400 for this parallel run (total 400)...
# Building estimator 227 of 400 for this parallel run (total 400)...
# Building estimator 228 of 400 for this parallel run (total 400)...
# Building estimator 229 of 400 for this parallel run (total 400)...
# Building estimator 230 of 400 for this parallel run (total 400)...
# Building estimator 231 of 400 for this parallel run (total 400)...
# Building estimator 232 of 400 for this parallel run (total 400)...
# Building estimator 233 of 400 for this parallel run (total 400)...
# Building estimator 234 of 400 for this parallel run (total 400)...
# Building estimator 235 of 400 for this parallel run (total 400)...
# Building estimator 236 of 400 for this parallel run (total 400)...
# Building estimator 237 of 400 for this parallel run (total 400)...
# Building estimator 238 of 400 for this parallel run (total 400)...
# Building estimator 239 of 400 for this parallel run (total 400)...
# Building estimator 240 of 400 for this parallel run (total 400)...
# Building estimator 241 of 400 for this parallel run (total 400)...
# Building estimator 242 of 400 for this parallel run (total 400)...
# Building estimator 243 of 400 for this parallel run (total 400)...
# Building estimator 244 of 400 for this parallel run (total 400)...
# Building estimator 245 of 400 for this parallel run (total 400)...
# Building estimator 246 of 400 for this parallel run (total 400)...
# Building estimator 247 of 400 for this parallel run (total 400)...
# Building estimator 248 of 400 for this parallel run (total 400)...
# Building estimator 249 of 400 for this parallel run (total 400)...
# Building estimator 250 of 400 for this parallel run (total 400)...
# Building estimator 251 of 400 for this parallel run (total 400)...
# Building estimator 252 of 400 for this parallel run (total 400)...
# Building estimator 253 of 400 for this parallel run (total 400)...
# Building estimator 254 of 400 for this parallel run (total 400)...
# Building estimator 255 of 400 for this parallel run (total 400)...
# Building estimator 256 of 400 for this parallel run (total 400)...
# Building estimator 257 of 400 for this parallel run (total 400)...
# Building estimator 258 of 400 for this parallel run (total 400)...
# Building estimator 259 of 400 for this parallel run (total 400)...
# Building estimator 260 of 400 for this parallel run (total 400)...
# Building estimator 261 of 400 for this parallel run (total 400)...
# Building estimator 262 of 400 for this parallel run (total 400)...
# Building estimator 263 of 400 for this parallel run (total 400)...
# Building estimator 264 of 400 for this parallel run (total 400)...
# Building estimator 265 of 400 for this parallel run (total 400)...
# Building estimator 266 of 400 for this parallel run (total 400)...
# Building estimator 267 of 400 for this parallel run (total 400)...
# Building estimator 268 of 400 for this parallel run (total 400)...
# Building estimator 269 of 400 for this parallel run (total 400)...
# Building estimator 270 of 400 for this parallel run (total 400)...
# Building estimator 271 of 400 for this parallel run (total 400)...
# Building estimator 272 of 400 for this parallel run (total 400)...
# Building estimator 273 of 400 for this parallel run (total 400)...
# Building estimator 274 of 400 for this parallel run (total 400)...
# Building estimator 275 of 400 for this parallel run (total 400)...
# Building estimator 276 of 400 for this parallel run (total 400)...
# Building estimator 277 of 400 for this parallel run (total 400)...
# Building estimator 278 of 400 for this parallel run (total 400)...
# Building estimator 279 of 400 for this parallel run (total 400)...
# Building estimator 280 of 400 for this parallel run (total 400)...
# Building estimator 281 of 400 for this parallel run (total 400)...
# Building estimator 282 of 400 for this parallel run (total 400)...
# Building estimator 283 of 400 for this parallel run (total 400)...
# Building estimator 284 of 400 for this parallel run (total 400)...
# Building estimator 285 of 400 for this parallel run (total 400)...
# Building estimator 286 of 400 for this parallel run (total 400)...
# Building estimator 287 of 400 for this parallel run (total 400)...
# Building estimator 288 of 400 for this parallel run (total 400)...
# Building estimator 289 of 400 for this parallel run (total 400)...
# Building estimator 290 of 400 for this parallel run (total 400)...
# Building estimator 291 of 400 for this parallel run (total 400)...
# Building estimator 292 of 400 for this parallel run (total 400)...
# Building estimator 293 of 400 for this parallel run (total 400)...
# Building estimator 294 of 400 for this parallel run (total 400)...
# Building estimator 295 of 400 for this parallel run (total 400)...
# Building estimator 296 of 400 for this parallel run (total 400)...
# Building estimator 297 of 400 for this parallel run (total 400)...
# Building estimator 298 of 400 for this parallel run (total 400)...
# Building estimator 299 of 400 for this parallel run (total 400)...
# Building estimator 300 of 400 for this parallel run (total 400)...
# Building estimator 301 of 400 for this parallel run (total 400)...
# Building estimator 302 of 400 for this parallel run (total 400)...
# Building estimator 303 of 400 for this parallel run (total 400)...
# Building estimator 304 of 400 for this parallel run (total 400)...
# Building estimator 305 of 400 for this parallel run (total 400)...
# Building estimator 306 of 400 for this parallel run (total 400)...
# Building estimator 307 of 400 for this parallel run (total 400)...
# Building estimator 308 of 400 for this parallel run (total 400)...
# Building estimator 309 of 400 for this parallel run (total 400)...
# Building estimator 310 of 400 for this parallel run (total 400)...
# Building estimator 311 of 400 for this parallel run (total 400)...
# Building estimator 312 of 400 for this parallel run (total 400)...
# Building estimator 313 of 400 for this parallel run (total 400)...
# Building estimator 314 of 400 for this parallel run (total 400)...
# Building estimator 315 of 400 for this parallel run (total 400)...
# Building estimator 316 of 400 for this parallel run (total 400)...
# Building estimator 317 of 400 for this parallel run (total 400)...
# Building estimator 318 of 400 for this parallel run (total 400)...
# Building estimator 319 of 400 for this parallel run (total 400)...
# Building estimator 320 of 400 for this parallel run (total 400)...
# Building estimator 321 of 400 for this parallel run (total 400)...
# Building estimator 322 of 400 for this parallel run (total 400)...
# Building estimator 323 of 400 for this parallel run (total 400)...
# Building estimator 324 of 400 for this parallel run (total 400)...
# Building estimator 325 of 400 for this parallel run (total 400)...
# Building estimator 326 of 400 for this parallel run (total 400)...
# Building estimator 327 of 400 for this parallel run (total 400)...
# Building estimator 328 of 400 for this parallel run (total 400)...
# Building estimator 329 of 400 for this parallel run (total 400)...
# Building estimator 330 of 400 for this parallel run (total 400)...
# Building estimator 331 of 400 for this parallel run (total 400)...
# Building estimator 332 of 400 for this parallel run (total 400)...
# Building estimator 333 of 400 for this parallel run (total 400)...
# Building estimator 334 of 400 for this parallel run (total 400)...
# Building estimator 335 of 400 for this parallel run (total 400)...
# Building estimator 336 of 400 for this parallel run (total 400)...
# Building estimator 337 of 400 for this parallel run (total 400)...
# Building estimator 338 of 400 for this parallel run (total 400)...
# Building estimator 339 of 400 for this parallel run (total 400)...
# Building estimator 340 of 400 for this parallel run (total 400)...
# Building estimator 341 of 400 for this parallel run (total 400)...
# Building estimator 342 of 400 for this parallel run (total 400)...
# Building estimator 343 of 400 for this parallel run (total 400)...
# Building estimator 344 of 400 for this parallel run (total 400)...
# Building estimator 345 of 400 for this parallel run (total 400)...
# Building estimator 346 of 400 for this parallel run (total 400)...
# Building estimator 347 of 400 for this parallel run (total 400)...
# Building estimator 348 of 400 for this parallel run (total 400)...
# Building estimator 349 of 400 for this parallel run (total 400)...
# Building estimator 350 of 400 for this parallel run (total 400)...
# Building estimator 351 of 400 for this parallel run (total 400)...
# Building estimator 352 of 400 for this parallel run (total 400)...
# Building estimator 353 of 400 for this parallel run (total 400)...
# Building estimator 354 of 400 for this parallel run (total 400)...
# Building estimator 355 of 400 for this parallel run (total 400)...
# Building estimator 356 of 400 for this parallel run (total 400)...
# Building estimator 357 of 400 for this parallel run (total 400)...
# Building estimator 358 of 400 for this parallel run (total 400)...
# Building estimator 359 of 400 for this parallel run (total 400)...
# Building estimator 360 of 400 for this parallel run (total 400)...
# Building estimator 361 of 400 for this parallel run (total 400)...
# Building estimator 362 of 400 for this parallel run (total 400)...
# Building estimator 363 of 400 for this parallel run (total 400)...
# Building estimator 364 of 400 for this parallel run (total 400)...
# Building estimator 365 of 400 for this parallel run (total 400)...
# Building estimator 366 of 400 for this parallel run (total 400)...
# Building estimator 367 of 400 for this parallel run (total 400)...
# Building estimator 368 of 400 for this parallel run (total 400)...
# Building estimator 369 of 400 for this parallel run (total 400)...
# Building estimator 370 of 400 for this parallel run (total 400)...
# Building estimator 371 of 400 for this parallel run (total 400)...
# Building estimator 372 of 400 for this parallel run (total 400)...
# Building estimator 373 of 400 for this parallel run (total 400)...
# Building estimator 374 of 400 for this parallel run (total 400)...
# Building estimator 375 of 400 for this parallel run (total 400)...
# Building estimator 376 of 400 for this parallel run (total 400)...
# Building estimator 377 of 400 for this parallel run (total 400)...
# Building estimator 378 of 400 for this parallel run (total 400)...
# Building estimator 379 of 400 for this parallel run (total 400)...
# Building estimator 380 of 400 for this parallel run (total 400)...
# Building estimator 381 of 400 for this parallel run (total 400)...
# Building estimator 382 of 400 for this parallel run (total 400)...
# Building estimator 383 of 400 for this parallel run (total 400)...
# Building estimator 384 of 400 for this parallel run (total 400)...
# Building estimator 385 of 400 for this parallel run (total 400)...
# Building estimator 386 of 400 for this parallel run (total 400)...
# Building estimator 387 of 400 for this parallel run (total 400)...
# Building estimator 388 of 400 for this parallel run (total 400)...
# Building estimator 389 of 400 for this parallel run (total 400)...
# Building estimator 390 of 400 for this parallel run (total 400)...
# Building estimator 391 of 400 for this parallel run (total 400)...
# Building estimator 392 of 400 for this parallel run (total 400)...
# Building estimator 393 of 400 for this parallel run (total 400)...
# Building estimator 394 of 400 for this parallel run (total 400)...
# Building estimator 395 of 400 for this parallel run (total 400)...
# Building estimator 396 of 400 for this parallel run (total 400)...
# Building estimator 397 of 400 for this parallel run (total 400)...
# Building estimator 398 of 400 for this parallel run (total 400)...
# Building estimator 399 of 400 for this parallel run (total 400)...
# Building estimator 400 of 400 for this parallel run (total 400)...
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   41.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   41.6s finished
# 0.9604395604395605

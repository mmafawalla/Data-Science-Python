# %% [markdown]
# # Hyper Parameter Tuning(GridSearchCV)
# Once we have selected the appropriate model for the data, how do we tune the parameter for the best model performance?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm_notebook as tqdm

# %% [markdown]
# ## Data

# %%
breast_cancer = pd.read_csv('../Data/breast_cancer.csv')
breast_cancer.drop(['id'], axis=1, inplace=True)
breast_cancer_dummies = pd.get_dummies(breast_cancer, columns=['diagnosis'], drop_first=True)
breast_cancer_dummies.rename(columns={'diagnosis_M': 'Malignant'}, inplace=True)
breast_cancer_dummies.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst  Malignant
# 0          0.4601                  0.11890          1
# 1          0.2750                  0.08902          1
# 2          0.3613                  0.08758          1
# 3          0.6638                  0.17300          1
# 4          0.2364                  0.07678          1
#
# [5 rows x 31 columns]

# %%
inputs = breast_cancer_dummies.drop(['Malignant'],axis=1)
target = breast_cancer_dummies.Malignant

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(inputs, target, test_size=0.2)

# %% [markdown]
# ## Model Selected: Random Forrest

# %%
from sklearn.ensemble import RandomForestClassifier
randomForrest = RandomForestClassifier()
randomForrest.fit(X_train, y_train)
randomForrest.score(X_test, y_test)
# Out:
# 0.956140350877193

# %% [markdown]
# ## Hyperparameters in Random Forrest

# %%
randomForrest.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# ## Important Hyperparameters
# Number of Trees(n_estimators): Any = 100,
# Number of features considered for splitting at each leaf node(max_features): Any = "auto",
# Maximum number of levels in each decision tree(max_depth): Any = None,
# Min number of data points allowed in a leaf node(min_samples_split): Any = 2,
# Sampling method with or without repalcement(bootstrap): Any = True,

# %% [markdown]
# # Random Grid Search
# We will first use random grid search(computationally mmore efficient) to randomnly find the best hyperparameters. From there we will hone into the best parameters using a sequential selection using Grid Search CV

# %%
from sklearn.model_selection import RandomizedSearchCV
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

# %%
rf_randomGridSearch = RandomizedSearchCV(estimator=RandomForestClassifier(), param_distributions=random_grid, n_iter=100, cv=3, verbose=3,
                                         n_jobs=-1)
rf_randomGridSearch.fit(X_train, y_train)
rf_randomGridSearch.best_params_
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# {'n_estimators': 1000,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'max_features': 'auto',
#  'max_depth': 50,
#  'bootstrap': True}

# %%
rf_randomGridSearch.score(X_test, y_test)
# Out:
# 0.9736842105263158

# %% [markdown]
# ## Grid Search CV

# %%
from sklearn.model_selection import GridSearchCV
params = {'n_estimators': [800,900,1000,1100, 1200],
          'min_samples_split': [1,2,3],
          'min_samples_leaf': [1,2,3],
          'max_features': [2,3],
          'max_depth': [30,40,50,60,70],
          'bootstrap': [True]}
rf_gridSearch = GridSearchCV(RandomForestClassifier(), param_grid=params, cv=3, return_train_score=False, verbose=3)
rf_gridSearch.fit(X_train, y_train)
df = pd.DataFrame(rf_gridSearch.cv_results_)
df
# Out:
# Fitting 3 folds for each of 450 candidates, totalling 1350 fits
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=1, n_estimators=800;, score=nan total time=   0.2s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=1, n_estimators=800;, score=nan total time=   0.2s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=1, n_estimators=800;, score=nan total time=   0.2s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=1, n_estimators=900;, score=nan total time=   0.2s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=1, n_estimators=900;, score=nan total time=   0.2s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=1, n_estimators=900;, score=nan total time=   0.2s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=1, n_estimators=1000;, score=nan total time=   0.3s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=1, n_estimators=1000;, score=nan total time=   0.3s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=1, n_estimators=1000;, score=nan total time=   0.3s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=1, n_estimators=1100;, score=nan total time=   0.3s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=1, n_estimators=1100;, score=nan total time=   0.3s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=1, n_estimators=1100;, score=nan total time=   0.3s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=1, n_estimators=1200;, score=nan total time=   0.3s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=1, n_estimators=1200;, score=nan total time=   0.3s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=1, n_estimators=1200;, score=nan total time=   0.3s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=800;, score=0.980 total time=   0.8s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=800;, score=0.928 total time=   0.8s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=800;, score=0.967 total time=   0.8s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=900;, score=0.980 total time=   0.9s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=900;, score=0.934 total time=   0.9s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=900;, score=0.974 total time=   0.9s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=1000;, score=0.974 total time=   1.0s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=1000;, score=0.928 total time=   1.0s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=1000;, score=0.967 total time=   1.0s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=1100;, score=0.980 total time=   1.1s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=1100;, score=0.928 total time=   1.1s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=1100;, score=0.967 total time=   1.1s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=1200;, score=0.980 total time=   1.3s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=1200;, score=0.928 total time=   1.2s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=1200;, score=0.967 total time=   1.2s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=800;, score=0.967 total time=   0.8s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=800;, score=0.928 total time=   0.8s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=800;, score=0.967 total time=   0.8s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=900;, score=0.980 total time=   0.9s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=900;, score=0.928 total time=   0.9s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=900;, score=0.967 total time=   0.9s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=1000;, score=0.974 total time=   1.0s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=1000;, score=0.928 total time=   1.0s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=1000;, score=0.967 total time=   1.0s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=1100;, score=0.974 total time=   1.1s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=1100;, score=0.928 total time=   1.1s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=1100;, score=0.974 total time=   1.1s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=1200;, score=0.980 total time=   1.2s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=1200;, score=0.928 total time=   1.2s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=1200;, score=0.967 total time=   1.2s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=1, n_estimators=800;, score=nan total time=   0.2s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=1, n_estimators=800;, score=nan total time=   0.2s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=1, n_estimators=800;, score=nan total time=   0.2s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=1, n_estimators=900;, score=nan total time=   0.2s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=1, n_estimators=900;, score=nan total time=   0.2s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=1, n_estimators=900;, score=nan total time=   0.2s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=1, n_estimators=1000;, score=nan total time=   0.3s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=1, n_estimators=1000;, score=nan total time=   0.3s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=1, n_estimators=1000;, score=nan total time=   0.3s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=1, n_estimators=1100;, score=nan total time=   0.3s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=1, n_estimators=1100;, score=nan total time=   0.3s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=1, n_estimators=1100;, score=nan total time=   0.3s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=1, n_estimators=1200;, score=nan total time=   0.3s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=1, n_estimators=1200;, score=nan total time=   0.3s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=1, n_estimators=1200;, score=nan total time=   0.3s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=800;, score=0.974 total time=   0.8s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=800;, score=0.928 total time=   0.8s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=800;, score=0.967 total time=   0.8s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=900;, score=0.974 total time=   0.9s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=900;, score=0.928 total time=   0.9s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=900;, score=0.974 total time=   0.9s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=1000;, score=0.974 total time=   1.0s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=1000;, score=0.928 total time=   1.0s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=1000;, score=0.967 total time=   1.0s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=1100;, score=0.974 total time=   1.1s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=1100;, score=0.928 total time=   1.1s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=1100;, score=0.967 total time=   1.1s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=1200;, score=0.974 total time=   1.2s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=1200;, score=0.928 total time=   1.2s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=1200;, score=0.974 total time=   1.2s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=800;, score=0.974 total time=   0.8s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=800;, score=0.928 total time=   0.8s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=800;, score=0.967 total time=   0.8s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=900;, score=0.980 total time=   0.9s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=900;, score=0.928 total time=   0.9s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=900;, score=0.974 total time=   0.9s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=1000;, score=0.974 total time=   1.0s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=1000;, score=0.928 total time=   1.0s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=1000;, score=0.967 total time=   1.0s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=1100;, score=0.980 total time=   1.1s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=1100;, score=0.928 total time=   1.1s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=1100;, score=0.967 total time=   1.1s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=1200;, score=0.974 total time=   1.2s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=1200;, score=0.928 total time=   1.2s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=1200;, score=0.967 total time=   1.2s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=1, n_estimators=800;, score=nan total time=   0.2s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=1, n_estimators=800;, score=nan total time=   0.2s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=1, n_estimators=800;, score=nan total time=   0.2s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=1, n_estimators=900;, score=nan total time=   0.2s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=1, n_estimators=900;, score=nan total time=   0.2s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=1, n_estimators=900;, score=nan total time=   0.2s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=1, n_estimators=1000;, score=nan total time=   0.3s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=1, n_estimators=1000;, score=nan total time=   0.3s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=1, n_estimators=1000;, score=nan total time=   0.3s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=1, n_estimators=1100;, score=nan total time=   0.3s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=1, n_estimators=1100;, score=nan total time=   0.3s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=1, n_estimators=1100;, score=nan total time=   0.3s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=1, n_estimators=1200;, score=nan total time=   0.3s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=1, n_estimators=1200;, score=nan total time=   0.3s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=1, n_estimators=1200;, score=nan total time=   0.3s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=800;, score=0.980 total time=   0.8s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=800;, score=0.928 total time=   0.8s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=800;, score=0.967 total time=   0.8s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=900;, score=0.974 total time=   0.9s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=900;, score=0.928 total time=   0.9s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=900;, score=0.967 total time=   0.9s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=1000;, score=0.967 total time=   1.0s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=1000;, score=0.928 total time=   1.0s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=1000;, score=0.967 total time=   1.0s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=1100;, score=0.980 total time=   1.1s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=1100;, score=0.928 total time=   1.1s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=1100;, score=0.967 total time=   1.1s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=1200;, score=0.974 total time=   1.2s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=1200;, score=0.928 total time=   1.2s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=1200;, score=0.967 total time=   1.2s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=800;, score=0.974 total time=   0.8s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=800;, score=0.928 total time=   0.8s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=800;, score=0.967 total time=   0.8s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=900;, score=0.974 total time=   0.9s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=900;, score=0.928 total time=   0.9s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=900;, score=0.974 total time=   0.9s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=1000;, score=0.967 total time=   1.0s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=1000;, score=0.928 total time=   1.0s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=1000;, score=0.974 total time=   1.0s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=1100;, score=0.980 total time=   1.1s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=1100;, score=0.928 total time=   1.1s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=1100;, score=0.967 total time=   1.1s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=1200;, score=0.980 total time=   1.2s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=1200;, score=0.928 total time=   1.2s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=1200;, score=0.960 total time=   1.2s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=800;, score=nan total time=   0.2s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=800;, score=nan total time=   0.2s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=800;, score=nan total time=   0.2s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=900;, score=nan total time=   0.2s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=900;, score=nan total time=   0.2s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=900;, score=nan total time=   0.2s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=1000;, score=nan total time=   0.3s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=1000;, score=nan total time=   0.3s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=1000;, score=nan total time=   0.3s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=1100;, score=nan total time=   0.3s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=1100;, score=nan total time=   0.3s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=1100;, score=nan total time=   0.3s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=1200;, score=nan total time=   0.3s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=1200;, score=nan total time=   0.3s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=1200;, score=nan total time=   0.3s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=800;, score=0.980 total time=   0.8s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=800;, score=0.928 total time=   0.8s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=800;, score=0.974 total time=   0.8s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=900;, score=0.980 total time=   0.9s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=900;, score=0.934 total time=   0.9s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=900;, score=0.974 total time=   0.9s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=1000;, score=0.980 total time=   1.1s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=1000;, score=0.941 total time=   1.0s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=1000;, score=0.974 total time=   1.1s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=1100;, score=0.987 total time=   1.2s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=1100;, score=0.941 total time=   1.1s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=1100;, score=0.974 total time=   1.2s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=1200;, score=0.980 total time=   1.3s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=1200;, score=0.934 total time=   1.2s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=1200;, score=0.980 total time=   1.3s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=800;, score=0.980 total time=   0.8s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=800;, score=0.934 total time=   0.8s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=800;, score=0.974 total time=   0.9s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=900;, score=0.980 total time=   0.9s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=900;, score=0.934 total time=   0.9s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=900;, score=0.974 total time=   0.9s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=1000;, score=0.980 total time=   1.0s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=1000;, score=0.941 total time=   1.0s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=1000;, score=0.974 total time=   1.1s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=1100;, score=0.980 total time=   1.2s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=1100;, score=0.928 total time=   1.1s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=1100;, score=0.974 total time=   1.2s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=1200;, score=0.987 total time=   1.3s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=1200;, score=0.928 total time=   1.2s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=1200;, score=0.974 total time=   1.3s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=1, n_estimators=800;, score=nan total time=   0.2s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=1, n_estimators=800;, score=nan total time=   0.2s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=1, n_estimators=800;, score=nan total time=   0.2s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=1, n_estimators=900;, score=nan total time=   0.2s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=1, n_estimators=900;, score=nan total time=   0.2s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=1, n_estimators=900;, score=nan total time=   0.2s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=1, n_estimators=1000;, score=nan total time=   0.3s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=1, n_estimators=1000;, score=nan total time=   0.3s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=1, n_estimators=1000;, score=nan total time=   0.3s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=1, n_estimators=1100;, score=nan total time=   0.3s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=1, n_estimators=1100;, score=nan total time=   0.3s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=1, n_estimators=1100;, score=nan total time=   0.3s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=1, n_estimators=1200;, score=nan total time=   0.3s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=1, n_estimators=1200;, score=nan total time=   0.3s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=1, n_estimators=1200;, score=nan total time=   0.3s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=2, n_estimators=800;, score=0.980 total time=   0.8s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=2, n_estimators=800;, score=0.928 total time=   0.8s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=2, n_estimators=800;, score=0.967 total time=   0.9s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=2, n_estimators=900;, score=0.980 total time=   0.9s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=2, n_estimators=900;, score=0.928 total time=   0.9s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=2, n_estimators=900;, score=0.974 total time=   0.9s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=2, n_estimators=1000;, score=0.980 total time=   1.0s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=2, n_estimators=1000;, score=0.928 total time=   1.0s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=2, n_estimators=1000;, score=0.974 total time=   1.0s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=2, n_estimators=1100;, score=0.980 total time=   1.1s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=2, n_estimators=1100;, score=0.928 total time=   1.1s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=2, n_estimators=1100;, score=0.974 total time=   1.2s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=2, n_estimators=1200;, score=0.980 total time=   1.2s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=2, n_estimators=1200;, score=0.928 total time=   1.2s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=2, n_estimators=1200;, score=0.974 total time=   1.3s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=3, n_estimators=800;, score=0.980 total time=   0.8s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=3, n_estimators=800;, score=0.928 total time=   0.8s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=3, n_estimators=800;, score=0.967 total time=   0.8s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=3, n_estimators=900;, score=0.980 total time=   0.9s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=3, n_estimators=900;, score=0.928 total time=   0.9s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=3, n_estimators=900;, score=0.974 total time=   0.9s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=3, n_estimators=1000;, score=0.980 total time=   1.0s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=3, n_estimators=1000;, score=0.928 total time=   1.0s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=3, n_estimators=1000;, score=0.974 total time=   1.1s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=3, n_estimators=1100;, score=0.980 total time=   1.1s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=3, n_estimators=1100;, score=0.928 total time=   1.2s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=3, n_estimators=1100;, score=0.974 total time=   1.2s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=3, n_estimators=1200;, score=0.980 total time=   1.3s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=3, n_estimators=1200;, score=0.928 total time=   1.3s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=2, min_samples_split=3, n_estimators=1200;, score=0.967 total time=   1.2s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=1, n_estimators=800;, score=nan total time=   0.2s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=1, n_estimators=800;, score=nan total time=   0.2s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=1, n_estimators=800;, score=nan total time=   0.2s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=1, n_estimators=900;, score=nan total time=   0.2s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=1, n_estimators=900;, score=nan total time=   0.2s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=1, n_estimators=900;, score=nan total time=   0.2s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=1, n_estimators=1000;, score=nan total time=   0.3s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=1, n_estimators=1000;, score=nan total time=   0.3s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=1, n_estimators=1000;, score=nan total time=   0.3s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=1, n_estimators=1100;, score=nan total time=   0.3s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=1, n_estimators=1100;, score=nan total time=   0.3s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=1, n_estimators=1100;, score=nan total time=   0.3s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=1, n_estimators=1200;, score=nan total time=   0.3s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=1, n_estimators=1200;, score=nan total time=   0.3s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=1, n_estimators=1200;, score=nan total time=   0.3s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=2, n_estimators=800;, score=0.974 total time=   0.8s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=2, n_estimators=800;, score=0.928 total time=   0.8s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=2, n_estimators=800;, score=0.967 total time=   0.8s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=2, n_estimators=900;, score=0.980 total time=   1.0s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=2, n_estimators=900;, score=0.921 total time=   0.9s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=2, n_estimators=900;, score=0.974 total time=   1.0s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=2, n_estimators=1000;, score=0.980 total time=   1.1s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=2, n_estimators=1000;, score=0.928 total time=   1.0s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=2, n_estimators=1000;, score=0.960 total time=   1.0s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=2, n_estimators=1100;, score=0.980 total time=   1.1s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=2, n_estimators=1100;, score=0.921 total time=   1.1s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=2, n_estimators=1100;, score=0.960 total time=   1.2s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=2, n_estimators=1200;, score=0.974 total time=   1.2s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=2, n_estimators=1200;, score=0.928 total time=   1.2s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=2, n_estimators=1200;, score=0.967 total time=   1.2s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=800;, score=0.974 total time=   0.8s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=800;, score=0.928 total time=   0.8s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=800;, score=0.974 total time=   0.8s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=900;, score=0.980 total time=   0.9s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=900;, score=0.928 total time=   0.9s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=900;, score=0.967 total time=   0.9s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=1000;, score=0.980 total time=   1.0s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=1000;, score=0.928 total time=   1.0s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=1000;, score=0.974 total time=   1.0s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=1100;, score=0.980 total time=   1.1s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=1100;, score=0.921 total time=   1.1s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=1100;, score=0.974 total time=   1.1s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=1200;, score=0.974 total time=   1.3s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=1200;, score=0.928 total time=   1.2s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=1200;, score=0.967 total time=   1.2s
# [CV 1/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=1, n_estimators=800;, score=nan total time=   0.2s
# [CV 2/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=1, n_estimators=800;, score=nan total time=   0.2s
# [CV 3/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=1, n_estimators=800;, score=nan total time=   0.2s
# [CV 1/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=1, n_estimators=900;, score=nan total time=   0.2s
# [CV 2/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=1, n_estimators=900;, score=nan total time=   0.2s
# [CV 3/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=1, n_estimators=900;, score=nan total time=   0.2s
# [CV 1/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=1, n_estimators=1000;, score=nan total time=   0.3s
# [CV 2/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=1, n_estimators=1000;, score=nan total time=   0.3s
# [CV 3/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=1, n_estimators=1000;, score=nan total time=   0.3s
# [CV 1/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=1, n_estimators=1100;, score=nan total time=   0.3s
# [CV 2/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=1, n_estimators=1100;, score=nan total time=   0.3s
# [CV 3/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=1, n_estimators=1100;, score=nan total time=   0.3s
# [CV 1/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=1, n_estimators=1200;, score=nan total time=   0.3s
# [CV 2/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=1, n_estimators=1200;, score=nan total time=   0.3s
# [CV 3/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=1, n_estimators=1200;, score=nan total time=   0.3s
# [CV 1/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=800;, score=0.980 total time=   0.8s
# [CV 2/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=800;, score=0.928 total time=   0.8s
# [CV 3/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=800;, score=0.967 total time=   0.8s
# [CV 1/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=900;, score=0.980 total time=   0.9s
# [CV 2/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=900;, score=0.928 total time=   0.9s
# [CV 3/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=900;, score=0.967 total time=   0.9s
# [CV 1/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=1000;, score=0.980 total time=   1.0s
# [CV 2/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=1000;, score=0.928 total time=   1.0s
# [CV 3/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=1000;, score=0.967 total time=   1.0s
# [CV 1/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=1100;, score=0.974 total time=   1.1s
# [CV 2/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=1100;, score=0.928 total time=   1.1s
# [CV 3/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=1100;, score=0.967 total time=   1.1s
# [CV 1/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=1200;, score=0.980 total time=   1.2s
# [CV 2/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=1200;, score=0.934 total time=   1.2s
# [CV 3/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=1200;, score=0.960 total time=   1.2s
# [CV 1/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=800;, score=0.980 total time=   0.8s
# [CV 2/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=800;, score=0.934 total time=   0.8s
# [CV 3/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=800;, score=0.974 total time=   0.8s
# [CV 1/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=900;, score=0.974 total time=   0.9s
# [CV 2/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=900;, score=0.928 total time=   0.9s
# [CV 3/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=900;, score=0.967 total time=   0.9s
# [CV 1/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=1000;, score=0.980 total time=   1.0s
# [CV 2/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=1000;, score=0.934 total time=   1.0s
# [CV 3/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=1000;, score=0.967 total time=   1.0s
# [CV 1/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=1100;, score=0.974 total time=   1.1s
# [CV 2/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=1100;, score=0.928 total time=   1.1s
# [CV 3/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=1100;, score=0.967 total time=   1.1s
# [CV 1/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=1200;, score=0.974 total time=   1.2s
# [CV 2/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=1200;, score=0.934 total time=   1.2s
# [CV 3/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=1200;, score=0.960 total time=   1.2s
# [CV 1/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=2, min_samples_split=1, n_estimators=800;, score=nan total time=   0.2s
# [CV 2/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=2, min_samples_split=1, n_estimators=800;, score=nan total time=   0.2s
# [CV 3/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=2, min_samples_split=1, n_estimators=800;, score=nan total time=   0.2s
# [CV 1/3] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=2, min_samples_split=1, n_estimators=900;, score=nan total time=   0.2s
# ...
# [CV 2/3] END bootstrap=True, max_depth=70, max_features=3, min_samples_leaf=3, min_samples_split=2, n_estimators=1000;, score=0.934 total time=   1.0s
# [CV 3/3] END bootstrap=True, max_depth=70, max_features=3, min_samples_leaf=3, min_samples_split=2, n_estimators=1000;, score=0.974 total time=   1.0s
# [CV 1/3] END bootstrap=True, max_depth=70, max_features=3, min_samples_leaf=3, min_samples_split=2, n_estimators=1100;, score=0.980 total time=   1.1s
# [CV 2/3] END bootstrap=True, max_depth=70, max_features=3, min_samples_leaf=3, min_samples_split=2, n_estimators=1100;, score=0.928 total time=   1.1s
# [CV 3/3] END bootstrap=True, max_depth=70, max_features=3, min_samples_leaf=3, min_samples_split=2, n_estimators=1100;, score=0.967 total time=   1.1s
# [CV 1/3] END bootstrap=True, max_depth=70, max_features=3, min_samples_leaf=3, min_samples_split=2, n_estimators=1200;, score=0.974 total time=   1.2s
# [CV 2/3] END bootstrap=True, max_depth=70, max_features=3, min_samples_leaf=3, min_samples_split=2, n_estimators=1200;, score=0.928 total time=   1.2s
# [CV 3/3] END bootstrap=True, max_depth=70, max_features=3, min_samples_leaf=3, min_samples_split=2, n_estimators=1200;, score=0.967 total time=   1.2s
# [CV 1/3] END bootstrap=True, max_depth=70, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=800;, score=0.974 total time=   0.8s
# [CV 2/3] END bootstrap=True, max_depth=70, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=800;, score=0.928 total time=   0.8s
# [CV 3/3] END bootstrap=True, max_depth=70, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=800;, score=0.974 total time=   0.8s
# [CV 1/3] END bootstrap=True, max_depth=70, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=900;, score=0.961 total time=   0.9s
# [CV 2/3] END bootstrap=True, max_depth=70, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=900;, score=0.928 total time=   0.9s
# [CV 3/3] END bootstrap=True, max_depth=70, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=900;, score=0.974 total time=   0.9s
# [CV 1/3] END bootstrap=True, max_depth=70, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=1000;, score=0.980 total time=   1.0s
# [CV 2/3] END bootstrap=True, max_depth=70, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=1000;, score=0.921 total time=   1.0s
# [CV 3/3] END bootstrap=True, max_depth=70, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=1000;, score=0.967 total time=   1.0s
# [CV 1/3] END bootstrap=True, max_depth=70, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=1100;, score=0.980 total time=   1.1s
# [CV 2/3] END bootstrap=True, max_depth=70, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=1100;, score=0.921 total time=   1.1s
# [CV 3/3] END bootstrap=True, max_depth=70, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=1100;, score=0.967 total time=   1.1s
# [CV 1/3] END bootstrap=True, max_depth=70, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=1200;, score=0.980 total time=   1.3s
# [CV 2/3] END bootstrap=True, max_depth=70, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=1200;, score=0.928 total time=   1.2s
# [CV 3/3] END bootstrap=True, max_depth=70, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=1200;, score=0.967 total time=   1.2s
# /Users/muhammedmafawalla/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 450 fits failed out of a total of 1350.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 450 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/muhammedmafawalla/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/muhammedmafawalla/lib/python3.7/site-packages/sklearn/ensemble/_forest.py", line 467, in fit
#     for i, t in enumerate(trees)
#   File "/Users/muhammedmafawalla/lib/python3.7/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/muhammedmafawalla/lib/python3.7/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/muhammedmafawalla/lib/python3.7/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/muhammedmafawalla/lib/python3.7/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/muhammedmafawalla/lib/python3.7/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#   File "/Users/muhammedmafawalla/lib/python3.7/site-packages/joblib/parallel.py", line 289, in __call__
#     for func, args, kwargs in self.items]
#   File "/Users/muhammedmafawalla/lib/python3.7/site-packages/joblib/parallel.py", line 289, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "/Users/muhammedmafawalla/lib/python3.7/site-packages/sklearn/utils/fixes.py", line 216, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/muhammedmafawalla/lib/python3.7/site-packages/sklearn/ensemble/_forest.py", line 185, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Users/muhammedmafawalla/lib/python3.7/site-packages/sklearn/tree/_classes.py", line 942, in fit
#     X_idx_sorted=X_idx_sorted,
#   File "/Users/muhammedmafawalla/lib/python3.7/site-packages/sklearn/tree/_classes.py", line 254, in fit
#     % self.min_samples_split
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/muhammedmafawalla/lib/python3.7/site-packages/sklearn/model_selection/_search.py:972: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan 0.95826072
#  0.96266121 0.95606774 0.95826072 0.95826072 0.95387475 0.95826072
#  0.95606774 0.95827524 0.95826072        nan        nan        nan
#         nan        nan 0.95606774 0.95827524 0.95606774 0.95606774
#  0.95827524 0.95606774 0.96046822 0.95606774 0.95826072 0.95606774
#         nan        nan        nan        nan        nan 0.95826072
#  0.95606774 0.95387475 0.95826072 0.95606774 0.95606774 0.95827524
#  0.95608226 0.95826072 0.95605321        nan        nan        nan
#         nan        nan 0.96046822 0.96266121 0.96485419 0.96704717
#  0.96486871 0.96266121 0.96266121 0.96485419 0.96046822 0.96266121
#         nan        nan        nan        nan        nan 0.95826072
#  0.96046822 0.96046822 0.96046822 0.96046822 0.95826072 0.96046822
#  0.96046822 0.96046822 0.95826072        nan        nan        nan
#         nan        nan 0.95606774 0.95827524 0.95605321 0.95386023
#  0.95606774 0.95827524 0.95826072 0.96046822 0.95827524 0.95606774
#         nan        nan        nan        nan        nan 0.95826072
#  0.95826072 0.95826072 0.95606774 0.95824619 0.96266121 0.95606774
#  0.9604537  0.95606774 0.95605321        nan        nan        nan
#         nan        nan 0.95827524 0.95826072 0.95606774 0.95826072
#  0.95605321 0.95826072 0.95606774 0.95826072 0.95826072 0.95606774
#         nan        nan        nan        nan        nan 0.95387475
#  0.95827524 0.95606774 0.95606774 0.95606774 0.95387475 0.95606774
#  0.95826072 0.95606774 0.95826072        nan        nan        nan
#         nan        nan 0.96706169 0.96706169 0.96266121 0.9604537
#  0.96266121 0.96706169 0.96485419 0.96264668 0.96485419 0.96266121
#         nan        nan        nan        nan        nan 0.96046822
#  0.96267573 0.95826072 0.96046822 0.96046822 0.95606774 0.95605321
#  0.96046822 0.96046822 0.96046822        nan        nan        nan
#         nan        nan 0.95606774 0.95605321 0.95606774 0.95606774
#  0.95826072 0.95606774 0.95826072 0.95827524 0.95826072 0.95827524
#         nan        nan        nan        nan        nan 0.95826072
#  0.95826072 0.95826072 0.9604537  0.96046822 0.9604537  0.95387475
#  0.95827524 0.95826072 0.95826072        nan        nan        nan
#         nan        nan 0.95606774 0.95826072 0.95826072 0.95827524
#  0.95826072 0.95386023 0.95606774 0.95826072 0.95387475 0.95605321
#         nan        nan        nan        nan        nan 0.95606774
#  0.95827524 0.95606774 0.95826072 0.95387475 0.95608226 0.95827524
#  0.95606774 0.95827524 0.95827524        nan        nan        nan
#         nan        nan 0.96266121 0.96264668 0.96485419 0.96046822
#  0.96266121 0.96266121 0.96046822 0.96046822 0.96266121 0.96046822
#         nan        nan        nan        nan        nan 0.95826072
#  0.96266121 0.96046822 0.96046822 0.96267573 0.96048275 0.95606774
#  0.96046822 0.95826072 0.96267573        nan        nan        nan
#         nan        nan 0.96046822 0.95826072 0.95605321 0.95827524
#  0.95606774 0.95826072 0.95826072 0.96046822 0.95826072 0.95827524
#         nan        nan        nan        nan        nan 0.95606774
#  0.96046822 0.95608226 0.95606774 0.95606774 0.95826072 0.95826072
#  0.95826072 0.95826072 0.95606774        nan        nan        nan
#         nan        nan 0.95826072 0.95606774 0.95826072 0.95826072
#  0.95827524 0.95606774 0.95827524 0.95827524 0.95826072 0.95826072
#         nan        nan        nan        nan        nan 0.95826072
#  0.95387475 0.95606774 0.96046822 0.95826072 0.95386023 0.95387475
#  0.95606774 0.95606774 0.95606774        nan        nan        nan
#         nan        nan 0.95826072 0.96485419 0.96046822 0.96267573
#  0.96706169 0.9604537  0.96266121 0.96046822 0.96046822 0.96266121
#         nan        nan        nan        nan        nan 0.95826072
#  0.96046822 0.95827524 0.96046822 0.96267573 0.96046822 0.95826072
#  0.96046822 0.96046822 0.96267573        nan        nan        nan
#         nan        nan 0.95606774 0.96046822 0.95826072 0.95826072
#  0.95827524 0.96046822 0.96046822 0.96046822 0.96046822 0.9604537
#         nan        nan        nan        nan        nan 0.95606774
#  0.95826072 0.95826072 0.95826072 0.95606774 0.95826072 0.95606774
#  0.95606774 0.95826072 0.95606774        nan        nan        nan
#         nan        nan 0.95606774 0.95387475 0.95606774 0.95606774
#  0.95606774 0.95826072 0.95386023 0.95606774 0.95826072 0.96046822
#         nan        nan        nan        nan        nan 0.95827524
#  0.95386023 0.95606774 0.95826072 0.95826072 0.96046822 0.94947427
#  0.95606774 0.95606774 0.96046822        nan        nan        nan
#         nan        nan 0.96046822 0.96266121 0.96485419 0.95826072
#  0.96046822 0.96266121 0.96046822 0.96046822 0.96046822 0.96046822
#         nan        nan        nan        nan        nan 0.96486871
#  0.96046822 0.96486871 0.96046822 0.96048275 0.96046822 0.95827524
#  0.96046822 0.96046822 0.96046822        nan        nan        nan
#         nan        nan 0.95606774 0.95826072 0.96046822 0.95826072
#  0.95606774 0.95827524 0.95388928 0.95606774 0.95606774 0.95826072]
#   category=UserWarning,
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.216596      0.001091         0.000000        0.000000
# 1         0.241624      0.000251         0.000000        0.000000
# 2         0.267052      0.000347         0.000000        0.000000
# 3         0.293965      0.000476         0.000000        0.000000
# 4         0.322271      0.002548         0.000000        0.000000
# ..             ...           ...              ...             ...
# 445       0.760257      0.006038         0.056330        0.000575
# 446       0.861687      0.003725         0.062850        0.000255
# 447       0.951820      0.010196         0.070365        0.001702
# 448       1.050758      0.001452         0.076247        0.000114
# 449       1.154033      0.023182         0.082699        0.000209
#
#     param_bootstrap param_max_depth param_max_features param_min_samples_leaf  \
# 0              True              30                  2                      1
# 1              True              30                  2                      1
# 2              True              30                  2                      1
# 3              True              30                  2                      1
# 4              True              30                  2                      1
# ..              ...             ...                ...                    ...
# 445            True              70                  3                      3
# 446            True              70                  3                      3
# 447            True              70                  3                      3
# 448            True              70                  3                      3
# 449            True              70                  3                      3
#
#     param_min_samples_split param_n_estimators  \
# 0                         1                800
# 1                         1                900
# 2                         1               1000
# 3                         1               1100
# 4                         1               1200
# ..                      ...                ...
# 445                       3                800
# 446                       3                900
# 447                       3               1000
# 448                       3               1100
# 449                       3               1200
#
#                                                 params  split0_test_score  \
# 0    {'bootstrap': True, 'max_depth': 30, 'max_feat...                NaN
# 1    {'bootstrap': True, 'max_depth': 30, 'max_feat...                NaN
# 2    {'bootstrap': True, 'max_depth': 30, 'max_feat...                NaN
# 3    {'bootstrap': True, 'max_depth': 30, 'max_feat...                NaN
# 4    {'bootstrap': True, 'max_depth': 30, 'max_feat...                NaN
# ..                                                 ...                ...
# 445  {'bootstrap': True, 'max_depth': 70, 'max_feat...           0.973684
# 446  {'bootstrap': True, 'max_depth': 70, 'max_feat...           0.960526
# 447  {'bootstrap': True, 'max_depth': 70, 'max_feat...           0.980263
# 448  {'bootstrap': True, 'max_depth': 70, 'max_feat...           0.980263
# 449  {'bootstrap': True, 'max_depth': 70, 'max_feat...           0.980263
#
#      split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0                  NaN                NaN              NaN             NaN
# 1                  NaN                NaN              NaN             NaN
# 2                  NaN                NaN              NaN             NaN
# 3                  NaN                NaN              NaN             NaN
# 4                  NaN                NaN              NaN             NaN
# ..                 ...                ...              ...             ...
# 445           0.927632           0.973510         0.958275        0.021668
# 446           0.927632           0.973510         0.953889        0.019309
# 447           0.921053           0.966887         0.956068        0.025354
# 448           0.921053           0.966887         0.956068        0.025354
# 449           0.927632           0.966887         0.958261        0.022336
#
#      rank_test_score
# 0                450
# 1                339
# 2                337
# 3                336
# 4                335
# ..               ...
# 445              108
# 446              284
# 447              211
# 448              211
# 449              135
#
# [450 rows x 17 columns]

# %% [markdown]
# # How to select a model for a dataset
#
# We will select between 3 models to classify observations in our breast cancer dataset:
# * Logistic Regression
# * Random Forrest
# * Support Vector Machine

# %%
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression

# Initialise model params dictionary
model_params = {
    'random_forrest': {
        'model': RandomForestClassifier(),
        'params': {'bootstrap': [True], 'max_depth': [60], 'max_features': [3], 'min_samples_leaf': [1], 'min_samples_split': [2], 'n_estimators': [1200]}
    },
    'svm': {
        'model': SVC(gamma='auto'),
        'params': {'kernel': ['linear', 'rbf'], 'C': [1,10,20]}
    },
    'logistic_regression': {
        'model': LogisticRegression(max_iter=10000),
        'params': {'C': [1,5,10]}
    }
}

# %%
scores = []

for model_name, mp in model_params.items():
    classifier = GridSearchCV(mp['model'], mp['params'], cv=3, return_train_score=False, verbose=3)
    classifier.fit(X_train, y_train)
    scores.append({
        'model': model_name,
        'best_score': classifier.best_score_,
        'best_params': classifier.best_params_
    })
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END bootstrap=True, max_depth=60, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=1200;, score=0.967 total time=   1.4s
# [CV 2/3] END bootstrap=True, max_depth=60, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=1200;, score=0.954 total time=   1.3s
# [CV 3/3] END bootstrap=True, max_depth=60, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=1200;, score=0.940 total time=   1.2s
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# [CV 1/3] END ................C=1, kernel=linear;, score=0.941 total time=   0.4s
# [CV 2/3] END ................C=1, kernel=linear;, score=0.954 total time=   0.2s
# [CV 3/3] END ................C=1, kernel=linear;, score=0.934 total time=   2.4s
# [CV 1/3] END ...................C=1, kernel=rbf;, score=0.638 total time=   0.0s
# [CV 2/3] END ...................C=1, kernel=rbf;, score=0.638 total time=   0.0s
# [CV 3/3] END ...................C=1, kernel=rbf;, score=0.636 total time=   0.0s
# [CV 1/3] END ...............C=10, kernel=linear;, score=0.954 total time=   2.1s
# [CV 2/3] END ...............C=10, kernel=linear;, score=0.947 total time=   1.6s
# [CV 3/3] END ...............C=10, kernel=linear;, score=0.947 total time=   2.6s
# [CV 1/3] END ..................C=10, kernel=rbf;, score=0.638 total time=   0.0s
# [CV 2/3] END ..................C=10, kernel=rbf;, score=0.638 total time=   0.0s
# [CV 3/3] END ..................C=10, kernel=rbf;, score=0.636 total time=   0.0s
# [CV 1/3] END ...............C=20, kernel=linear;, score=0.954 total time=   2.0s
# [CV 2/3] END ...............C=20, kernel=linear;, score=0.934 total time=   1.2s
# [CV 3/3] END ...............C=20, kernel=linear;, score=0.947 total time=   0.6s
# [CV 1/3] END ..................C=20, kernel=rbf;, score=0.638 total time=   0.0s
# [CV 2/3] END ..................C=20, kernel=rbf;, score=0.638 total time=   0.0s
# [CV 3/3] END ..................C=20, kernel=rbf;, score=0.636 total time=   0.0s
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# [CV 1/3] END ...............................C=1;, score=0.954 total time=   0.0s
# [CV 2/3] END ...............................C=1;, score=0.947 total time=   0.2s
# [CV 3/3] END ...............................C=1;, score=0.947 total time=   0.2s
# [CV 1/3] END ...............................C=5;, score=0.947 total time=   0.4s
# [CV 2/3] END ...............................C=5;, score=0.954 total time=   0.1s
# [CV 3/3] END ...............................C=5;, score=0.947 total time=   0.1s
# [CV 1/3] END ..............................C=10;, score=0.954 total time=   0.5s
# [CV 2/3] END ..............................C=10;, score=0.954 total time=   0.2s
# [CV 3/3] END ..............................C=10;, score=0.947 total time=   0.1s

# %%
df = pd.DataFrame(scores, columns=['model', 'best_score', 'best_params'])
df
# Out:
#                  model  best_score  \
# 0       random_forrest    0.953817
# 1                  svm    0.949445
# 2  logistic_regression    0.951638
#
#                                          best_params
# 0  {'bootstrap': True, 'max_depth': 60, 'max_feat...
# 1                      {'C': 10, 'kernel': 'linear'}
# 2                                          {'C': 10}

# %% [markdown]
# ## Scale Data

# %%
from sklearn.preprocessing import StandardScaler
inputs_transformed = StandardScaler().fit_transform(inputs)
X_train_scaled, X_test_scaled, y_train_scaled, y_test_scaled = train_test_split(inputs_transformed, target, test_size=0.2)

# %%
scores_scaled = []

for model_name, mp in model_params.items():
    classifier = GridSearchCV(mp['model'], mp['params'], cv=3, return_train_score=False, verbose=3)
    classifier.fit(X_train_scaled, y_train_scaled)
    scores_scaled.append({
        'model': model_name,
        'best_score': classifier.best_score_,
        'best_params': classifier.best_params_
    })
df = pd.DataFrame(scores_scaled, columns=['model', 'best_score', 'best_params'])
df
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END bootstrap=True, max_depth=60, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=1200;, score=0.974 total time=   1.3s
# [CV 2/3] END bootstrap=True, max_depth=60, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=1200;, score=0.967 total time=   1.2s
# [CV 3/3] END bootstrap=True, max_depth=60, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=1200;, score=0.954 total time=   1.2s
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# [CV 1/3] END ................C=1, kernel=linear;, score=0.961 total time=   0.0s
# [CV 2/3] END ................C=1, kernel=linear;, score=0.980 total time=   0.0s
# [CV 3/3] END ................C=1, kernel=linear;, score=0.980 total time=   0.0s
# [CV 1/3] END ...................C=1, kernel=rbf;, score=0.967 total time=   0.0s
# [CV 2/3] END ...................C=1, kernel=rbf;, score=0.980 total time=   0.0s
# [CV 3/3] END ...................C=1, kernel=rbf;, score=0.974 total time=   0.0s
# [CV 1/3] END ...............C=10, kernel=linear;, score=0.954 total time=   0.0s
# [CV 2/3] END ...............C=10, kernel=linear;, score=0.947 total time=   0.0s
# [CV 3/3] END ...............C=10, kernel=linear;, score=0.954 total time=   0.0s
# [CV 1/3] END ..................C=10, kernel=rbf;, score=0.967 total time=   0.0s
# [CV 2/3] END ..................C=10, kernel=rbf;, score=0.987 total time=   0.0s
# [CV 3/3] END ..................C=10, kernel=rbf;, score=0.980 total time=   0.0s
# [CV 1/3] END ...............C=20, kernel=linear;, score=0.954 total time=   0.0s
# [CV 2/3] END ...............C=20, kernel=linear;, score=0.947 total time=   0.0s
# [CV 3/3] END ...............C=20, kernel=linear;, score=0.947 total time=   0.0s
# [CV 1/3] END ..................C=20, kernel=rbf;, score=0.967 total time=   0.0s
# [CV 2/3] END ..................C=20, kernel=rbf;, score=0.980 total time=   0.0s
# [CV 3/3] END ..................C=20, kernel=rbf;, score=0.967 total time=   0.0s
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# [CV 1/3] END ...............................C=1;, score=0.961 total time=   0.0s
# [CV 2/3] END ...............................C=1;, score=0.974 total time=   0.0s
# [CV 3/3] END ...............................C=1;, score=0.987 total time=   0.0s
# [CV 1/3] END ...............................C=5;, score=0.961 total time=   0.0s
# [CV 2/3] END ...............................C=5;, score=0.967 total time=   0.0s
# [CV 3/3] END ...............................C=5;, score=0.980 total time=   0.0s
# [CV 1/3] END ..............................C=10;, score=0.961 total time=   0.0s
# [CV 2/3] END ..............................C=10;, score=0.954 total time=   0.0s
# [CV 3/3] END ..............................C=10;, score=0.980 total time=   0.0s
#                  model  best_score  \
# 0       random_forrest    0.964811
# 1                  svm    0.978027
# 2  logistic_regression    0.973655
#
#                                          best_params
# 0  {'bootstrap': True, 'max_depth': 60, 'max_feat...
# 1                         {'C': 10, 'kernel': 'rbf'}
# 2                                           {'C': 1}
